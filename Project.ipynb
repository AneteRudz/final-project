# %% [markdown]
# ## Importing modules

# %%
import pandas as pd
import numpy as np
import re
import nltk
    
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import *
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from textblob import TextBlob

# show all columns
pd.set_option('display.max_columns', None)

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')

# %% [markdown]
# ## Importing data

# %% [markdown]
# #### Original

# %%
listings = pd.read_csv('./Airbnb/listings.csv')

# %%
listings_details = pd.read_csv('./Airbnb/listings_details.csv')
# Out:
# C:\Users\anete\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
reviews_details = pd.read_csv('./Airbnb/reviews_details.csv')

# %%
calendar = pd.read_csv('./Airbnb/calendar.csv')

# %% [markdown]
# #### Listings cleaned

# %%
listings_clean = pd.read_csv('./Airbnb/listings_clean.csv')

# %%
listings_details_clean = pd.read_csv('./Airbnb/listings_details_clean.csv')

# %% [markdown]
# #### Current

# %%
listings_new = pd.read_csv('./Airbnb/listings_new.csv')
listings_new = listings_new.drop(columns=['Unnamed: 0'])

# %%
calendar_clean = pd.read_csv('./Airbnb/calendar_clean.csv')

# %% [markdown]
# ## Airbnb

# %%
listings.head()
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1   3209                  Quiet apt near center, great view     3806
# 2  20168         100%Centre-Studio 1 Private Floor/Bathroom    59484
# 3  25428                Lovely apt in City Centre (Jordaan)    56142
# 4  27886  Romantic, stylish B&B houseboat in canal district    97647
#
#   host_name  neighbourhood_group                           neighbourhood  \
# 0    Daniel                  NaN  Oostelijk Havengebied - Indische Buurt
# 1   Maartje                  NaN                              Westerpark
# 2      Alex                  NaN                            Centrum-Oost
# 3      Joan                  NaN                            Centrum-West
# 4      Flip                  NaN                            Centrum-West
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 0  52.365755   4.941419     Private room     59               3
# 1  52.390225   4.873924  Entire home/apt    160               4
# 2  52.365087   4.893541  Entire home/apt     80               1
# 3  52.373114   4.883668  Entire home/apt    125              14
# 4  52.386727   4.892078     Private room    150               2
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                248  2018-11-28               2.10
# 1                 42  2018-08-29               1.03
# 2                233  2018-11-30               2.18
# 3                  1  2018-01-21               0.09
# 4                171  2018-11-25               2.03
#
#    calculated_host_listings_count  availability_365
# 0                               1                44
# 1                               1                47
# 2                               2               198
# 3                               2               141
# 4                               1               199

# %%
listings.shape
# Out:
# (20030, 16)

# %%
listings_details.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2818  https://www.airbnb.com/rooms/2818  20181206172549   2018-12-06
# 1  3209  https://www.airbnb.com/rooms/3209  20181206172549   2018-12-06
#
#                                        name  \
# 0  Quiet Garden View Room & Super Fast WiFi
# 1         Quiet apt near center, great view
#
#                                              summary  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1  You will love our spacious (90 m2) bright apar...
#
#                                                space  \
# 0  I'm renting a bedroom (room overlooking the ga...
# 1  Our apartment has lots of light, a balcony and...
#
#                                          description experiences_offered  \
# 0  Quiet Garden View Room & Super Fast WiFi I'm r...                none
# 1  You will love our spacious (90 m2) bright apar...                none
#
#                                neighborhood_overview  \
# 0  Indische Buurt ("Indies Neighborhood") is a ne...
# 1  Welcome to the Spaarndammerbuurt! From the beg...
#
#                                                notes  \
# 0  From week 38 to week 47 maintenance work to th...
# 1                                                NaN
#
#                                              transit  \
# 0  The neighbourhood is well served by 24 hours p...
# 1  From Central Station, walk towards the busstop...
#
#                                         access  \
# 0                                          NaN
# 1  You will have the entire house to yourself.
#
#                                          interaction  \
# 0                                                NaN
# 1  We will meet you in person for check in whenev...
#
#                                          house_rules  thumbnail_url  \
# 0  Please: - Leave your shoes in the entrance  - ...            NaN
# 1  Our house comes with our very sweet, but old (...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/10272854/8...
# 1         NaN  https://a0.muscache.com/im/pictures/88955424/4...
#
#    xl_picture_url  host_id                                host_url host_name  \
# 0             NaN     3159  https://www.airbnb.com/users/show/3159    Daniel
# 1             NaN     3806  https://www.airbnb.com/users/show/3806   Maartje
#
#    host_since                              host_location  \
# 0  2008-09-24  Amsterdam, Noord-Holland, The Netherlands
# 1  2008-10-24  Amsterdam, Noord-Holland, The Netherlands
#
#                                           host_about host_response_time  \
# 0  Upon arriving in Amsterdam, one can imagine as...     within an hour
# 1  I am a freelance radio producer and journalist...     within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 t
# 1               100%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/3159/profile_...
# 1  https://a0.muscache.com/im/users/3806/profile_...
#
#                                     host_picture_url  \
# 0  https://a0.muscache.com/im/users/3159/profile_...
# 1  https://a0.muscache.com/im/users/3806/profile_...
#
#                host_neighbourhood  host_listings_count  \
# 0                  Indische Buurt                  1.0
# 1  Spaarndammer en Zeeheldenbuurt                  1.0
#
#    host_total_listings_count  \
# 0                        1.0
# 1                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1             ['email', 'phone', 'reviews', 'jumio']                    t
#
#   host_identity_verified                                 street  \
# 0                      f  Amsterdam, North Holland, Netherlands
# 1                      t  Amsterdam, Noord-Holland, Netherlands
#
#                     neighbourhood                  neighbourhood_cleansed  \
# 0                  Indische Buurt  Oostelijk Havengebied - Indische Buurt
# 1  Spaarndammer en Zeeheldenbuurt                              Westerpark
#
#    neighbourhood_group_cleansed       city          state  zipcode     market  \
# 0                           NaN  Amsterdam  North Holland      NaN  Amsterdam
# 1                           NaN  Amsterdam  Noord-Holland  1013 XE  Amsterdam
#
#            smart_location country_code      country   latitude  longitude  \
# 0  Amsterdam, Netherlands           NL  Netherlands  52.365755   4.941419
# 1  Amsterdam, Netherlands           NL  Netherlands  52.390225   4.873924
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 f     Apartment     Private room             2        1.5
# 1                 t     Apartment  Entire home/apt             5        1.0
#
#    bedrooms  beds  bed_type  \
# 0       1.0   2.0  Real Bed
# 1       2.0   2.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {Internet,Wifi,"Paid parking off premises","Bu...          NaN   $59.00
# 1  {Internet,Wifi,Kitchen,"Paid parking off premi...          NaN  $160.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN     $1,500.00          $100.00       $50.00                1
# 1      $543.00     $2,000.00          $300.00       $40.00                2
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0       $20.00               3              15            today
# 1       $15.00               4              20      7 weeks ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               17               44               44
# 1                t                0                0                0
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0                44            2018-12-06                248   2009-03-30
# 1                47            2018-12-06                 42   2015-07-31
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2018-11-28                  97.0                    10.0
# 1  2018-08-29                  96.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                 10.0
# 1                         10.0                     9.0                  9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN        {Amsterdam}                t
# 1                f     NaN        {Amsterdam}                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1               2.10
# 1                               1               1.03

# %%
listings_new.shape
# Out:
# (20030, 54)

# %%
reviews_details.head()
# Out:
#    listing_id    id        date  reviewer_id reviewer_name  \
# 0        2818  1191  2009-03-30        10952           Lam
# 1        2818  1771  2009-04-24        12798         Alice
# 2        2818  1989  2009-05-03        11869       Natalja
# 3        2818  2797  2009-05-18        14064       Enrique
# 4        2818  3151  2009-05-25        17977       Sherwin
#
#                                             comments
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...
# 2  We had such a great time in Amsterdam. Daniel ...
# 3  Very professional operation. Room is very clea...
# 4  Daniel is highly recommended.  He provided all...

# %%
reviews_details.shape
# Out:
# (431830, 6)

# %% [markdown]
# # Questions

# %%
"""
What to consider if you want to become a host at Airbnb?

- Predict the price based on all factors
- Price estimator for different neighborhoods

- What should be the price if you want to book now / in a week / in a month / in half a year? (per neighborhood)
- How is the total rating of an apartment affected by the factors?
- Comments:
     - what are the most informative features per neighborhood? What people like / don't like?
     - Naive Bayes
     
1. Comments:
    - Add a column with neighborhood
    - clean_up(), tokenize(), stem_and_lemmatize(), remove_stopwords()
    



"""

# %% [markdown]
# # Data cleaning

# %% [markdown]
# #### Calendar data

# %%
# Remove rows where apartments are not available

calendar_clean = calendar.dropna()
calendar_clean.dtypes
# Out:
# listing_id     int64
# date          object
# available     object
# price         object
# dtype: object

# %%
# Remove the dollar sign from 'price' column and conver to float
calendar_clean['price'] = calendar_clean['price'].replace({'\$': '', ',': ''}, regex=True)
calendar_clean['price'] = calendar_clean['price'].astype(float)

# Change the 'date' column to datetime
calendar_clean['date'] = pd.to_datetime(calendar_clean['date'])
# Out:
# C:\Users\anete\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#calendar_clean.to_csv('calendar_clean.csv')

# %% [markdown]
# #### Listings

# %%
listings.isnull().sum()

##################################################################
# where 'last_review' isnull - replace?
# where 'reviews_per_month' isnull - replace with 'no reviews'
# Out:
# id                                    0
# name                                 38
# host_id                               0
# host_name                             4
# neighbourhood_group               20030
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        2406
# reviews_per_month                  2406
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# drop ['neighbourhood_group', 'last_review', 'host_name', 'calculated_host_listings_count']
listings_clean = listings.drop(columns=['neighbourhood_group', 'last_review', 'host_name', 
                                        'calculated_host_listings_count', 'reviews_per_month', 'room_type',
                                       'minimum_nights', 'number_of_reviews'])

# %%
#listings_clean.to_csv('listings_clean.csv')

# %% [markdown]
# #### Listings (details)

# %%
listings_details_clean = listings_details.drop(columns=['space','summary','listing_url', 'scrape_id', 'last_scraped', 'name', 
                                               'experiences_offered', 'neighborhood_overview', 'notes',
                                               'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 
                                               'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name', 
                                               'host_acceptance_rate', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
                                               'street', 'neighbourhood', 'neighbourhood_group_cleansed', 'city', 'state', 'market', 
                                               'smart_location', 'country_code', 'country', 'latitude', 'longitude', 'square_feet', 
                                               'price', 'calendar_last_scraped', 'has_availability', 'jurisdiction_names', 'requires_license', 
                                               'license', 'is_business_travel_ready', 'zipcode', 'weekly_price', 'monthly_price',
                                                'host_about', 'host_location'])
listings_details_clean
# Out:
#              id                                        description  \
# 0          2818  Quiet Garden View Room & Super Fast WiFi I'm r...
# 1          3209  You will love our spacious (90 m2) bright apar...
# 2         20168  Cozy studio on your own private floor, 100% in...
# 3         25428  This nicely furnished, newly renovated apt  is...
# 4         27886  Stylish and romantic houseboat on fantastic hi...
# 5         28658  2 beds guest room in Amsterdam West near Erasm...
# 6         28871  In a monumental house right in the center of A...
# 7         29051  because of the city imposing a 4 paying guest ...
# 8         31080  My apartment is light and cosy.  The three bed...
# 9         41125  A nice, sunny and spacious apartment in the ce...
# 10        42970  A home away from home Great location Including...
# 11        43980  ASK FOR LONG TERM RELOCATION DEALS ! Ideal sta...
# 12        44129  Welcome to my little gem Cozy, bright and roma...
# 13        44391  . Fully furnished apartment in the center of A...
# 14        45246  Welcome to magical Amsterdam! This flat is loc...
# 15        46386  River view loft in quiet street in hip neighbo...
# 16        47061  A beautiful, quiet apartment in the center of ...
# 17        48076  Second and third floor apartment with very ste...
# 18        49790  Book right away, ill do everything to get u an...
# 19        50515  This is a beautiful family home in a lovely pa...
# 20        50518  Nice and clean, very close to the city center,...
# 21        50523  B & B “De 9 Straatjes” welcomes you to your ‘h...
# 22        50570  Very quiet and bright fully furnished 1-BR apa...
# 23        52490  Welcome to Amsterdam Aqua. My bright and spaci...
# 24        53067  Large studio in quiet street but in a good are...
# 25        53671  Our room with private bathroom (including show...
# 26        53692  On the first floor we have a bright studio ove...
# 27        55256  Room in the old city center near New Market. A...
# 28        55703  Great city apartment in a quiet residential ne...
# 29        55709  Charming, bright loft on the 5th floor with gr...
# ...         ...                                                ...
# 20000  30548247  BEAUTIFUL WESTERPARK AND CANAL IN FRONT OF THE...
# 20001  30548352  90 m2 apartment in fairly new building at walk...
# 20002  30548840  90 m2 apartment in fairly new building at walk...
# 20003  30549080  We can offer you one complete house. It includ...
# 20004  30549104  **brand new** Sleeping up to 2 guests in luxur...
# 20005  30549124  This Airbnb is located in a charming monumenta...
# 20006  30549659  Luxury and light apartment close to Vondelpark...
# 20007  30550093  1 private bedroom for two people (two single b...
# 20008  30551447  In the famous Amsterdam-West, just 15 minutes ...
# 20009  30551479  Nieuwezijds Kolk is a private apartment, situa...
# 20010  30552137  Luxury apartment located in a peaceful street ...
# 20011  30553458  On the lower level are the two cozy bedrooms a...
# 20012  30553701  High end luxury apartment in East Quarter, fea...
# 20013  30553840  The living room features a large flat screen T...
# 20014  30553943  The custom made double sofa bed in the living ...
# 20015  30554026  The open plan design kitchen is equipped with ...
# 20016  30556050  Pictures to be added this weekend!  A modern a...
# 20017  30556632  Our Loft apartment welcomes you to the heart o...
# 20018  30556768  I am offering my entire apartment for 2 separa...
# 20019  30556993  In this sweet home designed with traditional t...
# 20020  30561688                                                NaN
# 20021  30562273  Designer apartment in the South of Amsterdam, ...
# 20022  30562689  Spacious 100m2 two floor apartment with a big ...
# 20023  30563877  Apartments with a cozy renovation, located in ...
# 20024  30573892  The studio is located on the 4th floor of a re...
# 20025  30576148  Spacious (160m2) family house + FREE private p...
# 20026  30577727  My Home Sweet Home is a beautiful apartment th...
# 20027  30578037  Lightful apartment with 1 room available in th...
# 20028  30579673  My Home Sweet Home is a beautiful apartment th...
# 20029  30580413  Live like a local in our cosy 50m2 appartment ...
#
#        host_since  host_response_time host_response_rate host_is_superhost  \
# 0      2008-09-24      within an hour               100%                 t
# 1      2008-10-24      within an hour               100%                 f
# 2      2009-12-02  within a few hours               100%                 f
# 3      2009-11-20  within a few hours               100%                 f
# 4      2010-03-23      within an hour               100%                 t
# 5      2010-05-12      within an hour               100%                 f
# 6      2010-05-13      within an hour               100%                 t
# 7      2010-05-13      within an hour               100%                 t
# 8      2010-05-27  a few days or more                 0%                 f
# 9      2010-07-23  within a few hours               100%                 f
# 10     2010-08-01      within an hour               100%                 t
# 11     2009-12-22  within a few hours               100%                 f
# 12     2010-08-01        within a day                91%                 t
# 13     2010-08-08      within an hour               100%                 f
# 14     2010-08-13      within an hour               100%                 f
# 15     2010-08-20                 NaN                NaN                 f
# 16     2010-08-24      within an hour               100%                 f
# 17     2010-08-31      within an hour                80%                 t
# 18     2010-09-07      within an hour               100%                 f
# 19     2010-09-12        within a day                67%                 f
# 20     2010-09-12      within an hour               100%                 t
# 21     2010-09-12      within an hour               100%                 t
# 22     2010-09-12        within a day               100%                 f
# 23     2010-07-30                 NaN                NaN                 f
# 24     2010-09-27      within an hour               100%                 f
# 25     2010-09-28      within an hour               100%                 f
# 26     2010-09-27      within an hour               100%                 f
# 27     2010-10-13      within an hour               100%                 f
# 28     2010-10-16        within a day               100%                 f
# 29     2010-10-16      within an hour               100%                 f
# ...           ...                 ...                ...               ...
# 20000  2013-01-08                 NaN                NaN                 f
# 20001  2014-04-24                 NaN                NaN                 f
# 20002  2014-04-24                 NaN                NaN                 f
# 20003  2016-07-23      within an hour               100%                 f
# 20004  2017-01-30      within an hour                99%                 f
# 20005  2017-02-21                 NaN                NaN                 f
# 20006  2012-11-24                 NaN                NaN                 f
# 20007  2010-11-25      within an hour               100%                 f
# 20008  2014-12-21  within a few hours                88%                 t
# 20009  2017-09-21      within an hour               100%                 f
# 20010  2016-01-03      within an hour               100%                 f
# 20011  2018-12-05                 NaN                NaN                 f
# 20012  2018-12-05                 NaN                NaN                 f
# 20013  2018-12-05                 NaN                NaN                 f
# 20014  2018-12-05                 NaN                NaN                 f
# 20015  2018-12-05                 NaN                NaN                 f
# 20016  2014-10-19        within a day                50%                 t
# 20017  2018-12-05                 NaN                NaN                 f
# 20018  2014-04-08                 NaN                NaN                 f
# 20019  2018-12-04                 NaN                NaN                 f
# 20020  2018-12-03                 NaN                NaN                 f
# 20021  2011-07-22                 NaN                NaN                 f
# 20022  2018-12-05                 NaN                NaN                 f
# 20023  2018-12-02                 NaN                NaN                 f
# 20024  2018-12-06                 NaN                NaN                 f
# 20025  2014-03-22                 NaN                NaN                 f
# 20026  2012-01-11                 NaN                NaN                 f
# 20027  2016-08-04                 NaN                NaN                 f
# 20028  2012-01-11                 NaN                NaN                 f
# 20029  2015-02-04                 NaN                NaN                 f
#
#        host_listings_count  host_total_listings_count  \
# 0                      1.0                        1.0
# 1                      1.0                        1.0
# 2                      2.0                        2.0
# 3                      2.0                        2.0
# 4                      1.0                        1.0
# 5                      2.0                        2.0
# 6                      3.0                        3.0
# 7                      3.0                        3.0
# 8                      1.0                        1.0
# 9                      1.0                        1.0
# 10                     2.0                        2.0
# 11                     2.0                        2.0
# 12                    11.0                       11.0
# 13                     1.0                        1.0
# 14                     1.0                        1.0
# 15                     1.0                        1.0
# 16                     1.0                        1.0
# 17                     2.0                        2.0
# 18                     1.0                        1.0
# 19                     1.0                        1.0
# 20                     1.0                        1.0
# 21                     1.0                        1.0
# 22                     3.0                        3.0
# 23                     1.0                        1.0
# 24                     5.0                        5.0
# 25                     1.0                        1.0
# 26                     5.0                        5.0
# 27                     1.0                        1.0
# 28                     1.0                        1.0
# 29                     3.0                        3.0
# ...                    ...                        ...
# 20000                  1.0                        1.0
# 20001                  2.0                        2.0
# 20002                  2.0                        2.0
# 20003                  2.0                        2.0
# 20004                 38.0                       38.0
# 20005                  1.0                        1.0
# 20006                  1.0                        1.0
# 20007                  1.0                        1.0
# 20008                  4.0                        4.0
# 20009                  1.0                        1.0
# 20010                  2.0                        2.0
# 20011                  5.0                        5.0
# 20012                  5.0                        5.0
# 20013                  5.0                        5.0
# 20014                  5.0                        5.0
# 20015                  5.0                        5.0
# 20016                  1.0                        1.0
# 20017                  1.0                        1.0
# 20018                  1.0                        1.0
# 20019                  1.0                        1.0
# 20020                  1.0                        1.0
# 20021                  2.0                        2.0
# 20022                  1.0                        1.0
# 20023                  1.0                        1.0
# 20024                  1.0                        1.0
# 20025                  1.0                        1.0
# 20026                  2.0                        2.0
# 20027                  2.0                        2.0
# 20028                  2.0                        2.0
# 20029                  1.0                        1.0
#
#                                       host_verifications host_has_profile_pic  \
# 0      ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1                 ['email', 'phone', 'reviews', 'jumio']                    t
# 2      ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 3                          ['email', 'phone', 'reviews']                    t
# 4                 ['email', 'phone', 'reviews', 'jumio']                    t
# 5      ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 6                 ['email', 'phone', 'reviews', 'jumio']                    t
# 7                 ['email', 'phone', 'reviews', 'jumio']                    t
# 8      ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 9      ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 10                ['email', 'phone', 'reviews', 'jumio']                    t
# 11                         ['email', 'phone', 'reviews']                    t
# 12                         ['email', 'phone', 'reviews']                    t
# 13     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 14     ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 15     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 16     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 17             ['email', 'phone', 'facebook', 'reviews']                    t
# 18                         ['email', 'phone', 'reviews']                    t
# 19                ['email', 'phone', 'reviews', 'jumio']                    t
# 20     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 21     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 22     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 23                         ['email', 'phone', 'reviews']                    t
# 24     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 25     ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 26     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 27     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 28                ['email', 'phone', 'reviews', 'jumio']                    t
# 29                ['email', 'phone', 'reviews', 'jumio']                    t
# ...                                                  ...                  ...
# 20000  ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 20001  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 20002  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 20003                              ['phone', 'facebook']                    t
# 20004  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20005  ['email', 'phone', 'facebook', 'jumio', 'offli...                    t
# 20006  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 20007  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 20008  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20009                   ['email', 'phone', 'work_email']                    t
# 20010  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20011                                          ['phone']                    t
# 20012                                          ['phone']                    t
# 20013                                          ['phone']                    t
# 20014                                          ['phone']                    t
# 20015                                          ['phone']                    t
# 20016  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20017                                 ['email', 'phone']                    t
# 20018  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20019  ['email', 'phone', 'offline_government_id', 's...                    t
# 20020                                 ['email', 'phone']                    t
# 20021  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 20022                                          ['phone']                    t
# 20023                                 ['email', 'phone']                    t
# 20024                                 ['email', 'phone']                    t
# 20025                                 ['email', 'phone']                    t
# 20026                      ['email', 'phone', 'reviews']                    t
# 20027          ['email', 'phone', 'facebook', 'reviews']                    t
# 20028                      ['email', 'phone', 'reviews']                    t
# 20029          ['email', 'phone', 'facebook', 'reviews']                    t
#
#       host_identity_verified                  neighbourhood_cleansed  \
# 0                          f  Oostelijk Havengebied - Indische Buurt
# 1                          t                              Westerpark
# 2                          f                            Centrum-Oost
# 3                          f                            Centrum-West
# 4                          t                            Centrum-West
# 5                          t                           Bos en Lommer
# 6                          t                            Centrum-West
# 7                          t                            Centrum-West
# 8                          t                                    Zuid
# 9                          t                            Centrum-West
# 10                         f                            Centrum-West
# 11                         f                                    Zuid
# 12                         t                            Centrum-West
# 13                         t                            Centrum-Oost
# 14                         t                              Westerpark
# 15                         t                 De Pijp - Rivierenbuurt
# 16                         t                  De Baarsjes - Oud-West
# 17                         f                            Centrum-West
# 18                         f                  De Baarsjes - Oud-West
# 19                         t                           Bos en Lommer
# 20                         f                              Westerpark
# 21                         f                            Centrum-West
# 22                         t                           Bos en Lommer
# 23                         f  Oostelijk Havengebied - Indische Buurt
# 24                         t                 De Pijp - Rivierenbuurt
# 25                         t                              Westerpark
# 26                         t                 De Pijp - Rivierenbuurt
# 27                         t                            Centrum-Oost
# 28                         f                           Bos en Lommer
# 29                         t                            Centrum-Oost
# ...                      ...                                     ...
# 20000                      t                              Westerpark
# 20001                      t                             Slotervaart
# 20002                      t                             Slotervaart
# 20003                      f                            Centrum-Oost
# 20004                      f                  De Baarsjes - Oud-West
# 20005                      f                            Centrum-Oost
# 20006                      t                  De Baarsjes - Oud-West
# 20007                      f                 De Pijp - Rivierenbuurt
# 20008                      f                             Slotervaart
# 20009                      f                            Centrum-West
# 20010                      f                  De Baarsjes - Oud-West
# 20011                      f                                Oud-Oost
# 20012                      f                                Oud-Oost
# 20013                      f                                Oud-Oost
# 20014                      f                                Oud-Oost
# 20015                      f                                Oud-Oost
# 20016                      f                  De Baarsjes - Oud-West
# 20017                      f                            Centrum-Oost
# 20018                      t                                Oud-Oost
# 20019                      f                            Centrum-West
# 20020                      f                                  Osdorp
# 20021                      t                                    Zuid
# 20022                      f                         Watergraafsmeer
# 20023                      f                            Centrum-Oost
# 20024                      f                  De Baarsjes - Oud-West
# 20025                      f                         Watergraafsmeer
# 20026                      f  Oostelijk Havengebied - Indische Buurt
# 20027                      f                                Oud-Oost
# 20028                      f  Oostelijk Havengebied - Indische Buurt
# 20029                      f                 De Pijp - Rivierenbuurt
#
#       is_location_exact      property_type        room_type  accommodates  \
# 0                     f          Apartment     Private room             2
# 1                     t          Apartment  Entire home/apt             5
# 2                     t          Townhouse  Entire home/apt             2
# 3                     f          Apartment  Entire home/apt             3
# 4                     t          Houseboat     Private room             2
# 5                     t          Apartment     Private room             2
# 6                     t          Apartment     Private room             2
# 7                     t          Apartment     Private room             1
# 8                     f          Apartment  Entire home/apt             4
# 9                     f          Apartment  Entire home/apt             2
# 10                    t  Bed and breakfast     Private room             2
# 11                    f          Apartment  Entire home/apt             2
# 12                    t          Apartment  Entire home/apt             3
# 13                    t          Apartment  Entire home/apt             4
# 14                    t          Apartment  Entire home/apt             2
# 15                    t          Apartment  Entire home/apt             2
# 16                    t          Apartment  Entire home/apt             3
# 17                    t          Apartment  Entire home/apt             4
# 18                    t               Boat  Entire home/apt             4
# 19                    f          Townhouse  Entire home/apt             6
# 20                    f          Apartment  Entire home/apt             2
# 21                    f  Bed and breakfast     Private room             2
# 22                    f          Apartment  Entire home/apt             3
# 23                    f          Apartment     Private room             2
# 24                    f        Guest suite     Private room             2
# 25                    t        Guest suite     Private room             2
# 26                    f        Guest suite     Private room             4
# 27                    f          Apartment     Private room             2
# 28                    f          Apartment  Entire home/apt             4
# 29                    t               Loft  Entire home/apt             3
# ...                 ...                ...              ...           ...
# 20000                 t          Apartment  Entire home/apt             2
# 20001                 t          Apartment     Private room             2
# 20002                 t          Apartment  Entire home/apt             2
# 20003                 t          Townhouse  Entire home/apt             7
# 20004                 t          Apartment  Entire home/apt             2
# 20005                 t          Apartment     Private room             2
# 20006                 t          Apartment  Entire home/apt             2
# 20007                 f          Apartment     Private room             2
# 20008                 t          Apartment  Entire home/apt             6
# 20009                 t          Apartment  Entire home/apt             4
# 20010                 t          Apartment  Entire home/apt             4
# 20011                 f         Aparthotel  Entire home/apt             4
# 20012                 f         Aparthotel  Entire home/apt             4
# 20013                 f         Aparthotel  Entire home/apt             2
# 20014                 f         Aparthotel  Entire home/apt             2
# 20015                 f         Aparthotel  Entire home/apt             2
# 20016                 f          Apartment  Entire home/apt             4
# 20017                 t               Loft  Entire home/apt             2
# 20018                 t          Apartment  Entire home/apt             3
# 20019                 t          Apartment  Entire home/apt             4
# 20020                 f          Apartment  Entire home/apt             4
# 20021                 t          Apartment  Entire home/apt             4
# 20022                 t          Apartment  Entire home/apt             3
# 20023                 t          Apartment  Entire home/apt             4
# 20024                 t          Apartment  Entire home/apt             3
# 20025                 t              House  Entire home/apt             4
# 20026                 t          Apartment  Entire home/apt             3
# 20027                 f          Apartment  Entire home/apt             2
# 20028                 t          Apartment     Private room             2
# 20029                 t          Apartment  Entire home/apt             4
#
#        bathrooms  bedrooms  beds  bed_type  \
# 0            1.5       1.0   2.0  Real Bed
# 1            1.0       2.0   2.0  Real Bed
# 2            1.0       1.0   1.0  Real Bed
# 3            1.0       1.0   1.0  Real Bed
# 4            1.0       1.0   1.0  Real Bed
# 5            1.0       1.0   2.0  Real Bed
# 6            NaN       1.0   1.0  Real Bed
# 7            1.0       1.0   1.0  Real Bed
# 8            1.0       3.0   3.0  Real Bed
# 9            0.0       1.0   1.0  Real Bed
# 10           1.0       1.0   1.0  Real Bed
# 11           1.0       1.0   2.0  Real Bed
# 12           1.5       1.0   1.0  Real Bed
# 13           1.0       2.0   3.0  Real Bed
# 14           1.0       1.0   1.0  Real Bed
# 15           1.0       1.0   1.0  Real Bed
# 16           1.0       2.0   2.0  Real Bed
# 17           2.0       3.0   4.0  Real Bed
# 18           1.0       2.0   2.0  Real Bed
# 19           1.0       3.0   3.0  Real Bed
# 20           1.0       1.0   1.0  Real Bed
# 21           1.0       1.0   2.0  Real Bed
# 22           1.0       1.0   3.0  Real Bed
# 23           1.5       1.0   1.0  Real Bed
# 24           1.0       1.0   1.0  Real Bed
# 25           1.0       1.0   1.0  Real Bed
# 26           1.0       1.0   3.0  Real Bed
# 27           1.0       1.0   1.0     Futon
# 28           1.0       3.0   3.0  Real Bed
# 29           1.0       1.0   1.0  Real Bed
# ...          ...       ...   ...       ...
# 20000        1.0       1.0   1.0  Real Bed
# 20001        1.0       1.0   1.0  Real Bed
# 20002        1.0       0.0   1.0  Real Bed
# 20003        1.0       3.0   3.0  Real Bed
# 20004        1.0       1.0   1.0  Real Bed
# 20005        1.0       0.0   1.0  Real Bed
# 20006        1.5       2.0   2.0  Real Bed
# 20007        1.0       1.0   2.0  Real Bed
# 20008        1.5       3.0   2.0  Real Bed
# 20009        1.0       0.0   1.0  Real Bed
# 20010        1.0       2.0   2.0  Real Bed
# 20011        1.0       2.0   3.0  Real Bed
# 20012        1.0       2.0   3.0  Real Bed
# 20013        1.0       0.0   1.0  Real Bed
# 20014        1.0       1.0   2.0  Real Bed
# 20015        1.0       0.0   1.0  Real Bed
# 20016        1.0       2.0   2.0  Real Bed
# 20017        1.0       0.0   1.0  Real Bed
# 20018        1.0       2.0   2.0  Real Bed
# 20019        1.0       1.0   2.0  Real Bed
# 20020        1.0       1.0   2.0  Real Bed
# 20021        1.0       1.0   2.0  Real Bed
# 20022        1.0       2.0   1.0  Real Bed
# 20023        1.0       2.0   2.0  Real Bed
# 20024        1.0       0.0   2.0  Real Bed
# 20025        2.0       3.0   4.0  Real Bed
# 20026        1.0       2.0   3.0  Real Bed
# 20027        1.0       1.0   1.0  Real Bed
# 20028        1.0       1.0   1.0  Real Bed
# 20029        1.0       2.0   2.0  Real Bed
#
#                                                amenities security_deposit  \
# 0      {Internet,Wifi,"Paid parking off premises","Bu...          $100.00
# 1      {Internet,Wifi,Kitchen,"Paid parking off premi...          $300.00
# 2      {TV,Internet,Wifi,"Paid parking off premises",...              NaN
# 3      {TV,"Cable TV",Internet,Wifi,Kitchen,Elevator,...          $300.00
# 4      {TV,Internet,Wifi,Breakfast,Heating,"Smoke det...            $0.00
# 5      {TV,"Cable TV",Internet,Wifi,"Paid parking off...          $150.00
# 6      {TV,"Cable TV",Internet,Wifi,"Pets live on thi...              NaN
# 7      {TV,"Cable TV",Internet,Wifi,"Smoking allowed"...              NaN
# 8      {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...              NaN
# 9      {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...          $150.00
# 10     {TV,"Cable TV",Internet,Wifi,Heating,"Family/k...          $300.00
# 11     {TV,Internet,Wifi,Kitchen,"Paid parking off pr...          $300.00
# 12     {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...          $100.00
# 13     {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...            $0.00
# 14     {Wifi,Kitchen,"Paid parking off premises","Smo...              NaN
# 15     {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets all...          $250.00
# 16     {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,"...          $250.00
# 17     {TV,"Cable TV",Internet,Wifi,Kitchen,"Indoor f...            $0.00
# 18     {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,"...          $400.00
# 19     {TV,Wifi,Kitchen,"Paid parking off premises","...          $100.00
# 20     {"Cable TV",Wifi,Kitchen,"Paid parking off pre...            $0.00
# 21     {TV,"Cable TV",Internet,Wifi,Breakfast,Heating...              NaN
# 22     {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...            $0.00
# 23     {TV,Internet,Wifi,"Paid parking off premises",...            $0.00
# 24     {Internet,Wifi,"Smoking allowed",Heating,"Smok...            $0.00
# 25     {Wifi,"Paid parking off premises","Buzzer/wire...          $150.00
# 26     {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...            $0.00
# 27     {Internet,Wifi,Kitchen,"Paid parking off premi...            $0.00
# 28     {TV,"Cable TV",Internet,Wifi,"Wheelchair acces...          $500.00
# 29     {TV,"Cable TV",Wifi,Kitchen,"Paid parking off ...              NaN
# ...                                                  ...              ...
# 20000  {TV,Wifi,Kitchen,Breakfast,Washer,"Fire exting...          $500.00
# 20001  {TV,Wifi,Kitchen,Elevator,Heating,Washer,Essen...              NaN
# 20002  {TV,Wifi,Kitchen,Elevator,Heating,Washer,Essen...              NaN
# 20003  {Wifi,Kitchen,"Smoking allowed","Hot tub",Heat...              NaN
# 20004  {TV,Wifi,Kitchen,Heating,"Smoke detector","Fir...          $100.00
# 20005  {Wifi,"Air conditioning",Heating,Essentials,Sh...              NaN
# 20006  {TV,"Cable TV",Wifi,Kitchen,"Smoking allowed",...          $750.00
# 20007  {TV,Wifi,Kitchen,"Smoking allowed","Pets allow...              NaN
# 20008  {TV,Wifi,Kitchen,"Smoking allowed","Pets allow...              NaN
# 20009  {TV,Wifi,Kitchen,"Smoking allowed","Pets allow...              NaN
# 20010  {TV,Wifi,Kitchen,Heating,Washer,Dryer,Essentia...          $250.00
# 20011  {TV,"Cable TV",Wifi,Kitchen,Heating,"Smoke det...              NaN
# 20012  {TV,Wifi,Kitchen,Heating,"Smoke detector",Esse...              NaN
# 20013  {TV,Wifi,Kitchen,Heating,"Smoke detector",Esse...              NaN
# 20014  {TV,Wifi,Kitchen,Heating,"Smoke detector",Esse...              NaN
# 20015  {TV,Wifi,Kitchen,Heating,"Smoke detector",Esse...              NaN
# 20016  {Wifi,"Air conditioning",Kitchen,"Smoking allo...          $500.00
# 20017  {TV,Wifi,Kitchen,Heating,"Smoke detector","Car...            $0.00
# 20018  {TV,Wifi,Kitchen,"Smoking allowed",Heating,Was...          $250.00
# 20019  {TV,Wifi,Kitchen,"Smoking allowed",Breakfast,H...            $0.00
# 20020  {TV,Wifi,Kitchen,"Free parking on premises","S...              NaN
# 20021  {TV,Wifi,Kitchen,Heating,Washer,Dryer,"Smoke d...          $700.00
# 20022  {TV,Wifi,"Air conditioning",Kitchen,"Free park...              NaN
# 20023  {TV,Wifi,"Air conditioning",Pool,"Indoor firep...              NaN
# 20024  {Wifi,"Air conditioning",Kitchen,"Free parking...              NaN
# 20025  {TV,Wifi,Kitchen,"Free parking on premises",He...          $500.00
# 20026     {TV,Wifi,Kitchen,Essentials,"Hair dryer",Iron}            $0.00
# 20027  {TV,"Cable TV",Wifi,Kitchen,"Smoking allowed",...              NaN
# 20028     {TV,Wifi,Kitchen,Essentials,"Hair dryer",Iron}              NaN
# 20029  {TV,Wifi,Kitchen,"Pets allowed",Heating,Washer...            $0.00
#
#       cleaning_fee  guests_included extra_people  minimum_nights  \
# 0           $50.00                1       $20.00               3
# 1           $40.00                2       $15.00               4
# 2              NaN                2        $0.00               1
# 3           $40.00                2       $10.00              14
# 4            $0.00                1        $0.00               2
# 5           $15.00                2        $0.00               3
# 6              NaN                1        $0.00               2
# 7              NaN                1        $0.00               2
# 8           $60.00                4       $30.00               3
# 9           $40.00                2       $75.00               3
# 10          $35.00                1        $0.00               3
# 11          $50.00                4        $0.00              28
# 12          $60.00                2       $30.00               2
# 13          $50.00                2        $0.00               3
# 14             NaN                2       $20.00               3
# 15          $50.00                2       $50.00               3
# 16             NaN                2       $25.00               2
# 17           $0.00                4       $50.00               5
# 18          $50.00                2       $50.00               3
# 19          $75.00                4       $45.00               3
# 20          $30.00                2       $50.00               1
# 21             NaN                1        $0.00               2
# 22          $60.00                3       $25.00               4
# 23           $0.00                1        $0.00               3
# 24          $25.00                2        $0.00               1
# 25             NaN                1        $0.00               3
# 26          $25.00                3       $25.00               3
# 27          $15.00                1       $20.00               1
# 28          $50.00                1       $50.00               3
# 29          $35.00                2       $35.00               5
# ...            ...              ...          ...             ...
# 20000       $20.00                1        $0.00               2
# 20001          NaN                1        $0.00               3
# 20002          NaN                1        $0.00               4
# 20003       $50.00                1       $10.00               4
# 20004       $40.00                1        $0.00               2
# 20005          NaN                1        $0.00               1
# 20006       $45.00                2       $75.00               2
# 20007        $5.00                1        $0.00               1
# 20008          NaN                1        $0.00               4
# 20009          NaN                1        $0.00               1
# 20010       $50.00                1        $0.00               7
# 20011          NaN                1        $0.00               1
# 20012          NaN                1        $0.00               1
# 20013          NaN                1        $0.00               1
# 20014          NaN                1        $0.00               1
# 20015          NaN                1        $0.00               1
# 20016       $50.00                2       $50.00               3
# 20017       $50.00                1        $0.00               2
# 20018        $0.00                1        $0.00              14
# 20019       $30.00                3       $30.00               3
# 20020          NaN                1        $0.00               1
# 20021       $40.00                1       $20.00               2
# 20022          NaN                1        $0.00               5
# 20023          NaN                1        $0.00               7
# 20024          NaN                1        $0.00               1
# 20025       $60.00                1        $0.00               7
# 20026       $25.00                1        $0.00               3
# 20027          NaN                1        $0.00              10
# 20028          NaN                1        $0.00               2
# 20029       $30.00                1        $0.00               5
#
#        maximum_nights calendar_updated  availability_30  availability_60  \
# 0                  15            today               17               44
# 1                  20      7 weeks ago                0                0
# 2                1000            today                0                7
# 3                  60       2 days ago                2               32
# 4                 730            today               16               37
# 5                  15     2 months ago               11               29
# 6                1825        yesterday                3               10
# 7                 730            today                1               10
# 8                 365    16 months ago                1               31
# 9                  21            today                8                8
# 10               1100            today               14               33
# 11                365       3 days ago                0                0
# 12               1125            today               16               16
# 13                730      2 weeks ago                0                0
# 14                365       4 days ago                7               34
# 15               1825    11 months ago                0                0
# 16                 60      5 weeks ago                0                0
# 17                 30       2 days ago               12               35
# 18                365      2 weeks ago               13               43
# 19                 15     2 months ago                3                3
# 20               1120       a week ago                0                0
# 21                365       3 days ago                8               25
# 22                 30            today               19               19
# 23                 80       1 week ago               11               11
# 24                150            today                1                2
# 25                 14      4 weeks ago               22               25
# 26                150            today                0               16
# 27                365            today                6               21
# 28                 31      6 weeks ago                0                0
# 29                 30       a week ago                0                2
# ...               ...              ...              ...              ...
# 20000            1125        yesterday               12               12
# 20001            1125        yesterday                2               28
# 20002            1125            today               12               13
# 20003            1125        yesterday                7                7
# 20004            1125            today               29               56
# 20005            1125        yesterday               10               31
# 20006            1125            today               14               15
# 20007            1125            today                3                3
# 20008              17        yesterday               19               22
# 20009            1125        yesterday                1                1
# 20010              14        yesterday               14               15
# 20011            1125            today                9               19
# 20012            1125            today               14               29
# 20013            1125            today                8               18
# 20014            1125            today               23               49
# 20015            1125            today                8               18
# 20016            1125            today                8                9
# 20017               6            today               23               23
# 20018              24            today                0               24
# 20019            1125        yesterday               23               53
# 20020            1125            today               22               33
# 20021              15        yesterday               10               18
# 20022              15            today               10               10
# 20023            1125            today               11               22
# 20024            1125            today                7               33
# 20025              12            today               11               11
# 20026              14            today               14               16
# 20027              22            today                0                3
# 20028              15            today                7               31
# 20029            1125            today               14               14
#
#        availability_90  availability_365  number_of_reviews first_review  \
# 0                   44                44                248   2009-03-30
# 1                    0                47                 42   2015-07-31
# 2                   24               198                233   2010-03-02
# 3                   44               141                  1   2018-01-21
# 4                   54               199                171   2012-01-09
# 5                   52               295                434   2010-05-16
# 6                   17               137                215   2010-08-22
# 7                   18               188                383   2011-03-16
# 8                   61               336                 32   2011-08-06
# 9                   11                11                 76   2010-11-25
# 10                  63                89                426   2010-09-06
# 11                   5                10                 61   2010-11-01
# 12                  16                16                176   2010-08-16
# 13                   0                 0                 31   2010-09-16
# 14                  34               253                 79   2010-09-02
# 15                   0                 0                  3   2010-09-16
# 16                   0                 0                167   2010-09-13
# 17                  61               276                159   2011-10-02
# 18                  73               296                 98   2011-05-14
# 19                   3                79                 12   2014-04-17
# 20                   0                 0                 91   2012-10-24
# 21                  37               206                213   2011-01-04
# 22                  19                19                152   2011-03-31
# 23                  11                11                 81   2010-11-03
# 24                   2                 2                333   2010-11-21
# 25                  43               289                261   2011-04-12
# 26                  35                47                219   2011-06-04
# 27                  47               129                120   2011-02-20
# 28                   0                 0                  3   2015-08-10
# 29                   2                32                 53   2010-12-06
# ...                ...               ...                ...          ...
# 20000               12                12                  0          NaN
# 20001               28                28                  0          NaN
# 20002               13                13                  0          NaN
# 20003                7                 7                  0          NaN
# 20004               56                56                  0          NaN
# 20005               46               167                  0          NaN
# 20006               15                15                  0          NaN
# 20007                3                 3                  1   2018-12-06
# 20008               22                22                  0          NaN
# 20009                1                 1                  0          NaN
# 20010               15                15                  0          NaN
# 20011               44               296                  0          NaN
# 20012               42               302                  0          NaN
# 20013               34               283                  0          NaN
# 20014               79               350                  0          NaN
# 20015               34               297                  0          NaN
# 20016                9                 9                  0          NaN
# 20017               23                23                  0          NaN
# 20018               39                42                  0          NaN
# 20019               83                83                  0          NaN
# 20020               34                34                  0          NaN
# 20021               18                23                  0          NaN
# 20022               15               234                  0          NaN
# 20023               30                30                  0          NaN
# 20024               56               133                  0          NaN
# 20025               11                11                  0          NaN
# ...
# 11                             9.0                     9.0
# 12                            10.0                    10.0
# 13                            10.0                     9.0
# 14                            10.0                    10.0
# 15                             9.0                     8.0
# 16                            10.0                    10.0
# 17                            10.0                    10.0
# 18                            10.0                    10.0
# 19                             9.0                     8.0
# 20                            10.0                    10.0
# 21                            10.0                    10.0
# 22                            10.0                     8.0
# 23                            10.0                     9.0
# 24                            10.0                    10.0
# 25                            10.0                     9.0
# 26                             9.0                     9.0
# 27                            10.0                    10.0
# 28                             9.0                    10.0
# 29                            10.0                    10.0
# ...                            ...                     ...
# 20000                          NaN                     NaN
# 20001                          NaN                     NaN
# 20002                          NaN                     NaN
# 20003                          NaN                     NaN
# 20004                          NaN                     NaN
# 20005                          NaN                     NaN
# 20006                          NaN                     NaN
# 20007                         10.0                    10.0
# 20008                          NaN                     NaN
# 20009                          NaN                     NaN
# 20010                          NaN                     NaN
# 20011                          NaN                     NaN
# 20012                          NaN                     NaN
# 20013                          NaN                     NaN
# 20014                          NaN                     NaN
# 20015                          NaN                     NaN
# 20016                          NaN                     NaN
# 20017                          NaN                     NaN
# 20018                          NaN                     NaN
# 20019                          NaN                     NaN
# 20020                          NaN                     NaN
# 20021                          NaN                     NaN
# 20022                          NaN                     NaN
# 20023                          NaN                     NaN
# 20024                          NaN                     NaN
# 20025                          NaN                     NaN
# 20026                          NaN                     NaN
# 20027                          NaN                     NaN
# 20028                          NaN                     NaN
# 20029                          NaN                     NaN
#
#        review_scores_value instant_bookable          cancellation_policy  \
# 0                     10.0                t  strict_14_with_grace_period
# 1                      9.0                f                     moderate
# 2                      9.0                f  strict_14_with_grace_period
# 3                     10.0                f  strict_14_with_grace_period
# 4                     10.0                t  strict_14_with_grace_period
# 5                      9.0                f                     moderate
# 6                     10.0                f                     moderate
# 7                     10.0                f                     moderate
# 8                      9.0                f                     moderate
# 9                      9.0                f                     moderate
# 10                     9.0                t  strict_14_with_grace_period
# 11                     8.0                f  strict_14_with_grace_period
# 12                     9.0                f  strict_14_with_grace_period
# 13                     9.0                f                     moderate
# 14                     9.0                t  strict_14_with_grace_period
# 15                     8.0                f                     flexible
# 16                     9.0                f                     flexible
# 17                     9.0                t  strict_14_with_grace_period
# 18                     9.0                f  strict_14_with_grace_period
# 19                     9.0                f                     moderate
# 20                     9.0                t  strict_14_with_grace_period
# 21                    10.0                f                     moderate
# 22                     9.0                f  strict_14_with_grace_period
# 23                     9.0                f  strict_14_with_grace_period
# 24                     9.0                t                     moderate
# 25                     9.0                t                     flexible
# 26                     9.0                t                     moderate
# 27                     9.0                f                     flexible
# 28                     9.0                t                     flexible
# 29                    10.0                f  strict_14_with_grace_period
# ...                    ...              ...                          ...
# 20000                  NaN                f  strict_14_with_grace_period
# 20001                  NaN                f                     flexible
# 20002                  NaN                f                     flexible
# 20003                  NaN                f                     moderate
# 20004                  NaN                f                     moderate
# 20005                  NaN                f                     flexible
# 20006                  NaN                t  strict_14_with_grace_period
# 20007                  8.0                t                     flexible
# 20008                  NaN                f  strict_14_with_grace_period
# 20009                  NaN                t                     flexible
# 20010                  NaN                f                     flexible
# 20011                  NaN                t                     moderate
# 20012                  NaN                t                     moderate
# 20013                  NaN                t                     moderate
# 20014                  NaN                t                     moderate
# 20015                  NaN                t                     moderate
# 20016                  NaN                f  strict_14_with_grace_period
# 20017                  NaN                f                     flexible
# 20018                  NaN                f  strict_14_with_grace_period
# 20019                  NaN                t  strict_14_with_grace_period
# 20020                  NaN                f                     flexible
# 20021                  NaN                f  strict_14_with_grace_period
# 20022                  NaN                t                     flexible
# 20023                  NaN                f                     flexible
# 20024                  NaN                f                     flexible
# 20025                  NaN                f  strict_14_with_grace_period
# 20026                  NaN                f                     flexible
# 20027                  NaN                f                     moderate
# 20028                  NaN                f                     flexible
# 20029                  NaN                t                     flexible
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 f                                f
# 2                                 f                                f
# 3                                 f                                f
# 4                                 f                                f
# 5                                 t                                t
# 6                                 f                                f
# 7                                 f                                f
# 8                                 f                                f
# 9                                 f                                f
# 10                                f                                t
# 11                                t                                t
# 12                                f                                f
# 13                                f                                f
# 14                                f                                f
# 15                                f                                f
# 16                                f                                f
# 17                                f                                t
# 18                                f                                f
# 19                                f                                f
# 20                                f                                f
# 21                                f                                f
# 22                                f                                f
# 23                                t                                f
# 24                                f                                f
# 25                                f                                f
# 26                                f                                f
# 27                                f                                f
# 28                                f                                f
# 29                                f                                f
# ...                             ...                              ...
# 20000                             f                                f
# 20001                             f                                f
# 20002                             f                                f
# 20003                             f                                f
# 20004                             f                                f
# 20005                             f                                f
# 20006                             f                                f
# 20007                             f                                f
# 20008                             f                                f
# 20009                             f                                f
# 20010                             f                                f
# 20011                             f                                f
# 20012                             f                                f
# 20013                             f                                f
# 20014                             f                                f
# 20015                             f                                f
# 20016                             f                                f
# 20017                             f                                f
# 20018                             f                                f
# 20019                             f                                f
# 20020                             f                                f
# 20021                             f                                f
# 20022                             f                                f
# 20023                             f                                f
# 20024                             f                                f
# 20025                             f                                f
# 20026                             f                                f
# 20027                             f                                f
# 20028                             f                                f
# 20029                             f                                f
#
#        calculated_host_listings_count  reviews_per_month
# 0                                   1               2.10
# 1                                   1               1.03
# 2                                   2               2.18
# 3                                   2               0.09
# 4                                   1               2.03
# 5                                   2               4.16
# 6                                   3               2.13
# 7                                   3               4.07
# 8                                   1               0.36
# 9                                   1               0.78
# 10                                  2               4.24
# 11                                  2               0.62
# 12                                  4               1.74
# 13                                  1               0.31
# 14                                  1               0.79
# 15                                  1               0.03
# 16                                  1               1.67
# 17                                  2               1.82
# 18                                  1               1.06
# 19                                  1               0.21
# 20                                  1               1.22
# 21                                  1               2.21
# 22                                  2               1.62
# 23                                  1               0.82
# 24                                  5               3.40
# 25                                  1               2.80
# 26                                  5               2.40
# 27                                  1               1.26
# 28                                  1               0.07
# 29                                  1               0.54
# ...                               ...                ...
# 20000                               1                NaN
# 20001                               2                NaN
# 20002                               2                NaN
# 20003                               2                NaN
# 20004                              38                NaN
# 20005                               1                NaN
# 20006                               1                NaN
# 20007                               1               1.00
# 20008                               3                NaN
# 20009                               1                NaN
# 20010                               1                NaN
# 20011                               5                NaN
# 20012                               5                NaN
# 20013                               5                NaN
# 20014                               5                NaN
# 20015                               5                NaN
# 20016                               1                NaN
# 20017                               1                NaN
# 20018                               1                NaN
# 20019                               1                NaN
# 20020                               1                NaN
# 20021                               1                NaN
# 20022                               1                NaN
# 20023                               1                NaN
# 20024                               1                NaN
# 20025                               1                NaN
# 20026                               2                NaN
# 20027                               2                NaN
# 20028                               2                NaN
# 20029                               1                NaN
#
# [20030 rows x 48 columns]

# %%
listings_details_clean['cancellation_policy'].isnull().sum()
# Out:
# 0

# %%
listings_details_clean.host_response_rate.unique()
# Out:
# array(['100%', '0%', '91%', nan, '80%', '67%', '70%', '78%', '90%', '92%',
#        '50%', '95%', '71%', '40%', '75%', '33%', '93%', '96%', '98%',
#        '83%', '82%', '43%', '94%', '86%', '88%', '10%', '60%', '32%',
#        '25%', '46%', '76%', '57%', '45%', '73%', '63%', '97%', '89%',
#        '20%', '56%', '44%', '30%', '29%', '99%', '69%', '87%', '65%',
#        '17%', '77%', '27%', '38%', '62%', '58%', '74%', '47%', '55%',
#        '85%', '53%', '79%', '66%'], dtype=object)

# %%
listings_details_clean.isnull().sum()
# Out:
# id                                     0
# description                          124
# host_since                             4
# host_response_time                  9483
# host_response_rate                  9483
# host_is_superhost                      4
# host_listings_count                    4
# host_total_listings_count              4
# host_verifications                     0
# host_has_profile_pic                   4
# host_identity_verified                 4
# neighbourhood_cleansed                 0
# is_location_exact                      0
# property_type                          0
# room_type                              0
# accommodates                           0
# bathrooms                             10
# bedrooms                               8
# beds                                   7
# bed_type                               0
# amenities                              0
# security_deposit                    6166
# cleaning_fee                        3629
# guests_included                        0
# extra_people                           0
# minimum_nights                         0
# maximum_nights                         0
# calendar_updated                       0
# availability_30                        0
# availability_60                        0
# availability_90                        0
# availability_365                       0
# number_of_reviews                      0
# first_review                        2406
# last_review                         2406
# review_scores_rating                2639
# review_scores_accuracy              2649
# review_scores_cleanliness           2647
# review_scores_checkin               2661
# review_scores_communication         2652
# review_scores_location              2660
# review_scores_value                 2659
# instant_bookable                       0
# cancellation_policy                    0
# require_guest_profile_picture          0
# require_guest_phone_verification       0
# calculated_host_listings_count         0
# reviews_per_month                   2406
# dtype: int64

# %%
#listings_details_clean.to_csv('listings_details_clean.csv')

# %% [markdown]
# #### Reviews

# %%
reviews_details.head()
# Out:
#    listing_id    id        date  reviewer_id reviewer_name  \
# 0        2818  1191  2009-03-30        10952           Lam
# 1        2818  1771  2009-04-24        12798         Alice
# 2        2818  1989  2009-05-03        11869       Natalja
# 3        2818  2797  2009-05-18        14064       Enrique
# 4        2818  3151  2009-05-25        17977       Sherwin
#
#                                             comments
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...
# 2  We had such a great time in Amsterdam. Daniel ...
# 3  Very professional operation. Room is very clea...
# 4  Daniel is highly recommended.  He provided all...

# %%
reviews_details.dtypes
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
reviews_details.shape
# Out:
# (431830, 6)

# %%
reviews_details.listing_id.nunique()
# Out:
# 17624

# %% [markdown]
# #### Merge 'listings_clean' with 'listings_details_clean'

# %%
listings_clean = listings_clean.drop(columns=['Unnamed: 0', 'availability_365'])
listings_details_clean = listings_details_clean.drop(columns=['Unnamed: 0'])

# %%
# Merge 'listings_clean' with 'listings_details_clean' (on='id')

listings_new = pd.merge(listings_clean, listings_details_clean, on='id')

# %%
listings_new = pd.merge(listings_clean, listings_details_clean, on='id')

# %%
#listings_new.to_csv('listings_new.csv')

# %% [markdown]
# #### Clean 'listings_new'

# %%
# CONVERT:

# where 'security_deposit' is NaN check if can replace with 0 (no deposit OR NO INFO AVAILABLE?)
# where 'cleaning_fee' is NaN check if can replace with 0 (no fee for cleaning OR NO INFO AVAILABLE?)

# Convert to integers:
#    ['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin']
#    ['review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value']

################################

# CATEGORIES:

# ['host_response_time', 'host_is_superhost', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified']
# ['is_location_exact', 'property_type', 'room_type', 'bed_type', 'amenities', 'requires_license', 'instant_bookable']
# ['cancellation_policy', 'require_guest_profile_picture']

# %%
listings_new.head()
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1   3209                  Quiet apt near center, great view     3806
# 2  20168         100%Centre-Studio 1 Private Floor/Bathroom    59484
# 3  25428                Lovely apt in City Centre (Jordaan)    56142
# 4  27886  Romantic, stylish B&B houseboat in canal district    97647
#
#                             neighbourhood   latitude  longitude  price  \
# 0  Oostelijk Havengebied - Indische Buurt  52.365755   4.941419     59
# 1                              Westerpark  52.390225   4.873924    160
# 2                            Centrum-Oost  52.365087   4.893541     80
# 3                            Centrum-West  52.373114   4.883668    125
# 4                            Centrum-West  52.386727   4.892078    150
#
#                                          description  host_since  \
# 0  Quiet Garden View Room & Super Fast WiFi I'm r...  2008-09-24
# 1  You will love our spacious (90 m2) bright apar...  2008-10-24
# 2  Cozy studio on your own private floor, 100% in...  2009-12-02
# 3  This nicely furnished, newly renovated apt  is...  2009-11-20
# 4  Stylish and romantic houseboat on fantastic hi...  2010-03-23
#
#    host_response_time host_response_rate host_is_superhost  \
# 0      within an hour               100%                 t
# 1      within an hour               100%                 f
# 2  within a few hours               100%                 f
# 3  within a few hours               100%                 f
# 4      within an hour               100%                 t
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  1.0                        1.0
# 2                  2.0                        2.0
# 3                  2.0                        2.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1             ['email', 'phone', 'reviews', 'jumio']                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 3                      ['email', 'phone', 'reviews']                    t
# 4             ['email', 'phone', 'reviews', 'jumio']                    t
#
#   host_identity_verified                  neighbourhood_cleansed  \
# 0                      f  Oostelijk Havengebied - Indische Buurt
# 1                      t                              Westerpark
# 2                      f                            Centrum-Oost
# 3                      f                            Centrum-West
# 4                      t                            Centrum-West
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 f     Apartment     Private room             2        1.5
# 1                 t     Apartment  Entire home/apt             5        1.0
# 2                 t     Townhouse  Entire home/apt             2        1.0
# 3                 f     Apartment  Entire home/apt             3        1.0
# 4                 t     Houseboat     Private room             2        1.0
#
#    bedrooms  beds  bed_type  \
# 0       1.0   2.0  Real Bed
# 1       2.0   2.0  Real Bed
# 2       1.0   1.0  Real Bed
# 3       1.0   1.0  Real Bed
# 4       1.0   1.0  Real Bed
#
#                                            amenities security_deposit  \
# 0  {Internet,Wifi,"Paid parking off premises","Bu...          $100.00
# 1  {Internet,Wifi,Kitchen,"Paid parking off premi...          $300.00
# 2  {TV,Internet,Wifi,"Paid parking off premises",...              NaN
# 3  {TV,"Cable TV",Internet,Wifi,Kitchen,Elevator,...          $300.00
# 4  {TV,Internet,Wifi,Breakfast,Heating,"Smoke det...            $0.00
#
#   cleaning_fee  guests_included extra_people  minimum_nights  maximum_nights  \
# 0       $50.00                1       $20.00               3              15
# 1       $40.00                2       $15.00               4              20
# 2          NaN                2        $0.00               1            1000
# 3       $40.00                2       $10.00              14              60
# 4        $0.00                1        $0.00               2             730
#
#   calendar_updated  availability_30  availability_60  availability_90  \
# 0            today               17               44               44
# 1      7 weeks ago                0                0                0
# 2            today                0                7               24
# 3       2 days ago                2               32               44
# 4            today               16               37               54
#
#    availability_365  number_of_reviews first_review last_review  \
# 0                44                248   2009-03-30  2018-11-28
# 1                47                 42   2015-07-31  2018-08-29
# 2               198                233   2010-03-02  2018-11-30
# 3               141                  1   2018-01-21  2018-01-21
# 4               199                171   2012-01-09  2018-11-25
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  97.0                    10.0                       10.0
# 1                  96.0                    10.0                        9.0
# 2                  87.0                     9.0                       10.0
# 3                 100.0                    10.0                       10.0
# 4                  99.0                    10.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                     9.0
# 1                   10.0                         10.0                     9.0
# 2                    9.0                          9.0                    10.0
# 3                   10.0                         10.0                    10.0
# 4                   10.0                         10.0                    10.0
#
#    review_scores_value instant_bookable          cancellation_policy  \
# 0                 10.0                t  strict_14_with_grace_period
# 1                  9.0                f                     moderate
# 2                  9.0                f  strict_14_with_grace_period
# 3                 10.0                f  strict_14_with_grace_period
# 4                 10.0                t  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1               2.10
# 1                               1               1.03
# 2                               2               2.18
# 3                               2               0.09
# 4                               1               2.03

# %%
# ['first_review', 'last_review'] - convert to datetime

listings_new[['first_review', 'last_review']] = listings_new[['first_review', 'last_review']].apply(pd.to_datetime)

# %%
# Remove percentige sign from: 'host_response_rate'

listings_new['host_response_rate'] = listings_new['host_response_rate'].replace({'%': ''}, regex=True)
listings_new['host_response_rate'] = listings_new['host_response_rate'].astype(float)

# %%
# ['security_deposit', 'cleaning_fee', 'extra_people'] - remove dollar sign and convert to floats

listings_new[['security_deposit', 'cleaning_fee', 'extra_people']] = listings_new[[ 'security_deposit', 'cleaning_fee', 'extra_people']].replace({'\$': '', ',': ''}, regex=True)
listings_new[['security_deposit', 'cleaning_fee', 'extra_people']] = listings_new[['security_deposit', 'cleaning_fee', 'extra_people']].astype(float)

# %%
listings_new = listings_new.drop(columns = ['name', 'neighbourhood_cleansed', 'description'])

# %%
listings_new
# Out:
#              id    host_id                           neighbourhood   latitude  \
# 0          2818       3159  Oostelijk Havengebied - Indische Buurt  52.365755
# 1          3209       3806                              Westerpark  52.390225
# 2         20168      59484                            Centrum-Oost  52.365087
# 3         25428      56142                            Centrum-West  52.373114
# 4         27886      97647                            Centrum-West  52.386727
# 5         28658     123414                           Bos en Lommer  52.375342
# 6         28871     124245                            Centrum-West  52.367187
# 7         29051     124245                            Centrum-West  52.367725
# 8         31080     133488                                    Zuid  52.351321
# 9         41125     178515                            Centrum-West  52.378915
# 10        42970     187580                            Centrum-West  52.367814
# 11        43980      65041                                    Zuid  52.357456
# 12        44129     187728                            Centrum-West  52.380711
# 13        44391     194779                            Centrum-Oost  52.370170
# 14        45246     200188                              Westerpark  52.377676
# 15        46386     207342                 De Pijp - Rivierenbuurt  52.352470
# 16        47061     211696                  De Baarsjes - Oud-West  52.367986
# 17        48076     219080                            Centrum-West  52.380420
# 18        49790     227530                  De Baarsjes - Oud-West  52.362664
# 19        50515     231864                           Bos en Lommer  52.377272
# 20        50518     231806                              Westerpark  52.382006
# 21        50523     231946                            Centrum-West  52.368408
# 22        50570     232321                           Bos en Lommer  52.377737
# 23        52490     185836  Oostelijk Havengebied - Indische Buurt  52.370046
# 24        53067     246493                 De Pijp - Rivierenbuurt  52.353393
# 25        53671     247822                              Westerpark  52.389053
# 26        53692     246493                 De Pijp - Rivierenbuurt  52.353483
# 27        55256     260785                            Centrum-Oost  52.371257
# 28        55703     263214                           Bos en Lommer  52.375608
# 29        55709     263233                            Centrum-Oost  52.358956
# ...         ...        ...                                     ...        ...
# 20000  30548247    4625854                              Westerpark  52.384264
# 20001  30548352   14688389                             Slotervaart  52.354058
# 20002  30548840   14688389                             Slotervaart  52.353619
# 20003  30549080   85555149                            Centrum-Oost  52.364360
# 20004  30549104  113977564                  De Baarsjes - Oud-West  52.372277
# 20005  30549124  117457476                            Centrum-Oost  52.365725
# 20006  30549659    4230303                  De Baarsjes - Oud-West  52.360870
# 20007  30550093     298511                 De Pijp - Rivierenbuurt  52.354136
# 20008  30551447   25066435                             Slotervaart  52.355383
# 20009  30551479  151566094                            Centrum-West  52.375609
# 20010  30552137   53168103                  De Baarsjes - Oud-West  52.373199
# 20011  30553458  229196646                                Oud-Oost  52.359046
# 20012  30553701  229196646                                Oud-Oost  52.360440
# 20013  30553840  229196646                                Oud-Oost  52.360813
# 20014  30553943  229196646                                Oud-Oost  52.359684
# 20015  30554026  229196646                                Oud-Oost  52.359957
# 20016  30556050   22701985                  De Baarsjes - Oud-West  52.363157
# 20017  30556632  229260989                            Centrum-Oost  52.371920
# 20018  30556768   14041017                                Oud-Oost  52.362993
# 20019  30556993  229109698                            Centrum-West  52.370966
# 20020  30561688  228892275                                  Osdorp  52.357365
# 20021  30562273     853028                                    Zuid  52.351766
# 20022  30562689  229295710                         Watergraafsmeer  52.356327
# 20023  30563877  228749822                            Centrum-Oost  52.365812
# 20024  30573892  229361236                  De Baarsjes - Oud-West  52.363901
# 20025  30576148   13399651                         Watergraafsmeer  52.345999
# 20026  30577727    1595885  Oostelijk Havengebied - Indische Buurt  52.362412
# 20027  30578037   87866499                                Oud-Oost  52.362431
# 20028  30579673    1595885  Oostelijk Havengebied - Indische Buurt  52.363780
# 20029  30580413   27212057                 De Pijp - Rivierenbuurt  52.346911
#
#        longitude  price  host_since  host_response_time  host_response_rate  \
# 0       4.941419     59  2008-09-24      within an hour               100.0
# 1       4.873924    160  2008-10-24      within an hour               100.0
# 2       4.893541     80  2009-12-02  within a few hours               100.0
# 3       4.883668    125  2009-11-20  within a few hours               100.0
# 4       4.892078    150  2010-03-23      within an hour               100.0
# 5       4.857289     65  2010-05-12      within an hour               100.0
# 6       4.890918     75  2010-05-13      within an hour               100.0
# 7       4.891512     55  2010-05-13      within an hour               100.0
# 8       4.848383    219  2010-05-27  a few days or more                 0.0
# 9       4.883205    180  2010-07-23  within a few hours               100.0
# 10      4.890012    159  2010-08-01      within an hour               100.0
# 11      4.861242    100  2009-12-22  within a few hours               100.0
# 12      4.886104    250  2010-08-01        within a day                91.0
# 13      4.914378    200  2010-08-08      within an hour               100.0
# 14      4.876179    155  2010-08-13      within an hour               100.0
# 15      4.908254    150  2010-08-20                 NaN                 NaN
# 16      4.874469    140  2010-08-24      within an hour               100.0
# 17      4.894535    350  2010-08-31      within an hour                80.0
# 18      4.861032    225  2010-09-07      within an hour               100.0
# 19      4.839253    120  2010-09-12        within a day                67.0
# 20      4.878650    125  2010-09-12      within an hour               100.0
# 21      4.884134    115  2010-09-12      within an hour               100.0
# 22      4.848912     90  2010-09-12        within a day               100.0
# 23      4.938691     72  2010-07-30                 NaN                 NaN
# 24      4.900638     87  2010-09-27      within an hour               100.0
# 25      4.885589     75  2010-09-28      within an hour               100.0
# 26      4.900490     60  2010-09-27      within an hour               100.0
# 27      4.903513     86  2010-10-13      within an hour               100.0
# 28      4.858187    250  2010-10-16        within a day               100.0
# 29      4.897259    159  2010-10-16      within an hour               100.0
# ...          ...    ...         ...                 ...                 ...
# 20000   4.869887    120  2013-01-08                 NaN                 NaN
# 20001   4.839266     80  2014-04-24                 NaN                 NaN
# 20002   4.839640    150  2014-04-24                 NaN                 NaN
# 20003   4.884386    224  2016-07-23      within an hour               100.0
# 20004   4.858137     51  2017-01-30      within an hour                99.0
# 20005   4.882802    180  2017-02-21                 NaN                 NaN
# 20006   4.864572     57  2012-11-24                 NaN                 NaN
# 20007   4.887945     40  2010-11-25      within an hour               100.0
# 20008   4.840729    295  2014-12-21  within a few hours                88.0
# 20009   4.894486    100  2017-09-21      within an hour               100.0
# 20010   4.860484    175  2016-01-03      within an hour               100.0
# 20011   4.927039    242  2018-12-05                 NaN                 NaN
# 20012   4.927233    264  2018-12-05                 NaN                 NaN
# 20013   4.926849    154  2018-12-05                 NaN                 NaN
# 20014   4.927150    172  2018-12-05                 NaN                 NaN
# 20015   4.926044    132  2018-12-05                 NaN                 NaN
# 20016   4.875763    150  2014-10-19        within a day                50.0
# 20017   4.900377    150  2018-12-05                 NaN                 NaN
# 20018   4.925654     70  2014-04-08                 NaN                 NaN
# 20019   4.882705    280  2018-12-04                 NaN                 NaN
# 20020   4.784800    150  2018-12-03                 NaN                 NaN
# 20021   4.853029    150  2011-07-22                 NaN                 NaN
# 20022   4.933991     80  2018-12-05                 NaN                 NaN
# 20023   4.896044    200  2018-12-02                 NaN                 NaN
# 20024   4.878162     81  2018-12-06                 NaN                 NaN
# 20025   4.952145    340  2014-03-22                 NaN                 NaN
# 20026   4.932467    150  2012-01-11                 NaN                 NaN
# 20027   4.926912     80  2016-08-04                 NaN                 NaN
# 20028   4.932493     55  2012-01-11                 NaN                 NaN
# 20029   4.901932    220  2015-02-04                 NaN                 NaN
#
#       host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                     t                  1.0                        1.0
# 1                     f                  1.0                        1.0
# 2                     f                  2.0                        2.0
# 3                     f                  2.0                        2.0
# 4                     t                  1.0                        1.0
# 5                     f                  2.0                        2.0
# 6                     t                  3.0                        3.0
# 7                     t                  3.0                        3.0
# 8                     f                  1.0                        1.0
# 9                     f                  1.0                        1.0
# 10                    t                  2.0                        2.0
# 11                    f                  2.0                        2.0
# 12                    t                 11.0                       11.0
# 13                    f                  1.0                        1.0
# 14                    f                  1.0                        1.0
# 15                    f                  1.0                        1.0
# 16                    f                  1.0                        1.0
# 17                    t                  2.0                        2.0
# 18                    f                  1.0                        1.0
# 19                    f                  1.0                        1.0
# 20                    t                  1.0                        1.0
# 21                    t                  1.0                        1.0
# 22                    f                  3.0                        3.0
# 23                    f                  1.0                        1.0
# 24                    f                  5.0                        5.0
# 25                    f                  1.0                        1.0
# 26                    f                  5.0                        5.0
# 27                    f                  1.0                        1.0
# 28                    f                  1.0                        1.0
# 29                    f                  3.0                        3.0
# ...                 ...                  ...                        ...
# 20000                 f                  1.0                        1.0
# 20001                 f                  2.0                        2.0
# 20002                 f                  2.0                        2.0
# 20003                 f                  2.0                        2.0
# 20004                 f                 38.0                       38.0
# 20005                 f                  1.0                        1.0
# 20006                 f                  1.0                        1.0
# 20007                 f                  1.0                        1.0
# 20008                 t                  4.0                        4.0
# 20009                 f                  1.0                        1.0
# 20010                 f                  2.0                        2.0
# 20011                 f                  5.0                        5.0
# 20012                 f                  5.0                        5.0
# 20013                 f                  5.0                        5.0
# 20014                 f                  5.0                        5.0
# 20015                 f                  5.0                        5.0
# 20016                 t                  1.0                        1.0
# 20017                 f                  1.0                        1.0
# 20018                 f                  1.0                        1.0
# 20019                 f                  1.0                        1.0
# 20020                 f                  1.0                        1.0
# 20021                 f                  2.0                        2.0
# 20022                 f                  1.0                        1.0
# 20023                 f                  1.0                        1.0
# 20024                 f                  1.0                        1.0
# 20025                 f                  1.0                        1.0
# 20026                 f                  2.0                        2.0
# 20027                 f                  2.0                        2.0
# 20028                 f                  2.0                        2.0
# 20029                 f                  1.0                        1.0
#
#                                       host_verifications host_has_profile_pic  \
# 0      ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1                 ['email', 'phone', 'reviews', 'jumio']                    t
# 2      ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 3                          ['email', 'phone', 'reviews']                    t
# 4                 ['email', 'phone', 'reviews', 'jumio']                    t
# 5      ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 6                 ['email', 'phone', 'reviews', 'jumio']                    t
# 7                 ['email', 'phone', 'reviews', 'jumio']                    t
# 8      ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 9      ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 10                ['email', 'phone', 'reviews', 'jumio']                    t
# 11                         ['email', 'phone', 'reviews']                    t
# 12                         ['email', 'phone', 'reviews']                    t
# 13     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 14     ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 15     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 16     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 17             ['email', 'phone', 'facebook', 'reviews']                    t
# 18                         ['email', 'phone', 'reviews']                    t
# 19                ['email', 'phone', 'reviews', 'jumio']                    t
# 20     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 21     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 22     ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 23                         ['email', 'phone', 'reviews']                    t
# 24     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 25     ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 26     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 27     ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 28                ['email', 'phone', 'reviews', 'jumio']                    t
# 29                ['email', 'phone', 'reviews', 'jumio']                    t
# ...                                                  ...                  ...
# 20000  ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 20001  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 20002  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 20003                              ['phone', 'facebook']                    t
# 20004  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20005  ['email', 'phone', 'facebook', 'jumio', 'offli...                    t
# 20006  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 20007  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 20008  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20009                   ['email', 'phone', 'work_email']                    t
# 20010  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20011                                          ['phone']                    t
# 20012                                          ['phone']                    t
# 20013                                          ['phone']                    t
# 20014                                          ['phone']                    t
# 20015                                          ['phone']                    t
# 20016  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20017                                 ['email', 'phone']                    t
# 20018  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 20019  ['email', 'phone', 'offline_government_id', 's...                    t
# 20020                                 ['email', 'phone']                    t
# 20021  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 20022                                          ['phone']                    t
# 20023                                 ['email', 'phone']                    t
# 20024                                 ['email', 'phone']                    t
# 20025                                 ['email', 'phone']                    t
# 20026                      ['email', 'phone', 'reviews']                    t
# 20027          ['email', 'phone', 'facebook', 'reviews']                    t
# 20028                      ['email', 'phone', 'reviews']                    t
# 20029          ['email', 'phone', 'facebook', 'reviews']                    t
#
#       host_identity_verified is_location_exact      property_type  \
# 0                          f                 f          Apartment
# 1                          t                 t          Apartment
# 2                          f                 t          Townhouse
# 3                          f                 f          Apartment
# 4                          t                 t          Houseboat
# 5                          t                 t          Apartment
# 6                          t                 t          Apartment
# 7                          t                 t          Apartment
# 8                          t                 f          Apartment
# 9                          t                 f          Apartment
# 10                         f                 t  Bed and breakfast
# 11                         f                 f          Apartment
# 12                         t                 t          Apartment
# 13                         t                 t          Apartment
# 14                         t                 t          Apartment
# 15                         t                 t          Apartment
# 16                         t                 t          Apartment
# 17                         f                 t          Apartment
# 18                         f                 t               Boat
# 19                         t                 f          Townhouse
# 20                         f                 f          Apartment
# 21                         f                 f  Bed and breakfast
# 22                         t                 f          Apartment
# 23                         f                 f          Apartment
# 24                         t                 f        Guest suite
# 25                         t                 t        Guest suite
# 26                         t                 f        Guest suite
# 27                         t                 f          Apartment
# 28                         f                 f          Apartment
# 29                         t                 t               Loft
# ...                      ...               ...                ...
# 20000                      t                 t          Apartment
# 20001                      t                 t          Apartment
# 20002                      t                 t          Apartment
# 20003                      f                 t          Townhouse
# 20004                      f                 t          Apartment
# 20005                      f                 t          Apartment
# 20006                      t                 t          Apartment
# 20007                      f                 f          Apartment
# 20008                      f                 t          Apartment
# 20009                      f                 t          Apartment
# 20010                      f                 t          Apartment
# 20011                      f                 f         Aparthotel
# 20012                      f                 f         Aparthotel
# 20013                      f                 f         Aparthotel
# 20014                      f                 f         Aparthotel
# 20015                      f                 f         Aparthotel
# 20016                      f                 f          Apartment
# 20017                      f                 t               Loft
# 20018                      t                 t          Apartment
# 20019                      f                 t          Apartment
# 20020                      f                 f          Apartment
# 20021                      t                 t          Apartment
# 20022                      f                 t          Apartment
# 20023                      f                 t          Apartment
# 20024                      f                 t          Apartment
# 20025                      f                 t              House
# 20026                      f                 t          Apartment
# 20027                      f                 f          Apartment
# 20028                      f                 t          Apartment
# 20029                      f                 t          Apartment
#
#              room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0         Private room             2        1.5       1.0   2.0  Real Bed
# 1      Entire home/apt             5        1.0       2.0   2.0  Real Bed
# 2      Entire home/apt             2        1.0       1.0   1.0  Real Bed
# 3      Entire home/apt             3        1.0       1.0   1.0  Real Bed
# 4         Private room             2        1.0       1.0   1.0  Real Bed
# 5         Private room             2        1.0       1.0   2.0  Real Bed
# 6         Private room             2        NaN       1.0   1.0  Real Bed
# 7         Private room             1        1.0       1.0   1.0  Real Bed
# 8      Entire home/apt             4        1.0       3.0   3.0  Real Bed
# 9      Entire home/apt             2        0.0       1.0   1.0  Real Bed
# 10        Private room             2        1.0       1.0   1.0  Real Bed
# 11     Entire home/apt             2        1.0       1.0   2.0  Real Bed
# 12     Entire home/apt             3        1.5       1.0   1.0  Real Bed
# 13     Entire home/apt             4        1.0       2.0   3.0  Real Bed
# 14     Entire home/apt             2        1.0       1.0   1.0  Real Bed
# 15     Entire home/apt             2        1.0       1.0   1.0  Real Bed
# 16     Entire home/apt             3        1.0       2.0   2.0  Real Bed
# 17     Entire home/apt             4        2.0       3.0   4.0  Real Bed
# 18     Entire home/apt             4        1.0       2.0   2.0  Real Bed
# 19     Entire home/apt             6        1.0       3.0   3.0  Real Bed
# 20     Entire home/apt             2        1.0       1.0   1.0  Real Bed
# 21        Private room             2        1.0       1.0   2.0  Real Bed
# 22     Entire home/apt             3        1.0       1.0   3.0  Real Bed
# 23        Private room             2        1.5       1.0   1.0  Real Bed
# 24        Private room             2        1.0       1.0   1.0  Real Bed
# 25        Private room             2        1.0       1.0   1.0  Real Bed
# 26        Private room             4        1.0       1.0   3.0  Real Bed
# 27        Private room             2        1.0       1.0   1.0     Futon
# 28     Entire home/apt             4        1.0       3.0   3.0  Real Bed
# 29     Entire home/apt             3        1.0       1.0   1.0  Real Bed
# ...                ...           ...        ...       ...   ...       ...
# 20000  Entire home/apt             2        1.0       1.0   1.0  Real Bed
# 20001     Private room             2        1.0       1.0   1.0  Real Bed
# 20002  Entire home/apt             2        1.0       0.0   1.0  Real Bed
# 20003  Entire home/apt             7        1.0       3.0   3.0  Real Bed
# 20004  Entire home/apt             2        1.0       1.0   1.0  Real Bed
# 20005     Private room             2        1.0       0.0   1.0  Real Bed
# 20006  Entire home/apt             2        1.5       2.0   2.0  Real Bed
# 20007     Private room             2        1.0       1.0   2.0  Real Bed
# 20008  Entire home/apt             6        1.5       3.0   2.0  Real Bed
# 20009  Entire home/apt             4        1.0       0.0   1.0  Real Bed
# 20010  Entire home/apt             4        1.0       2.0   2.0  Real Bed
# 20011  Entire home/apt             4        1.0       2.0   3.0  Real Bed
# 20012  Entire home/apt             4        1.0       2.0   3.0  Real Bed
# 20013  Entire home/apt             2        1.0       0.0   1.0  Real Bed
# 20014  Entire home/apt             2        1.0       1.0   2.0  Real Bed
# 20015  Entire home/apt             2        1.0       0.0   1.0  Real Bed
# 20016  Entire home/apt             4        1.0       2.0   2.0  Real Bed
# 20017  Entire home/apt             2        1.0       0.0   1.0  Real Bed
# 20018  Entire home/apt             3        1.0       2.0   2.0  Real Bed
# 20019  Entire home/apt             4        1.0       1.0   2.0  Real Bed
# 20020  Entire home/apt             4        1.0       1.0   2.0  Real Bed
# 20021  Entire home/apt             4        1.0       1.0   2.0  Real Bed
# 20022  Entire home/apt             3        1.0       2.0   1.0  Real Bed
# 20023  Entire home/apt             4        1.0       2.0   2.0  Real Bed
# 20024  Entire home/apt             3        1.0       0.0   2.0  Real Bed
# 20025  Entire home/apt             4        2.0       3.0   4.0  Real Bed
# 20026  Entire home/apt             3        1.0       2.0   3.0  Real Bed
# 20027  Entire home/apt             2        1.0       1.0   1.0  Real Bed
# 20028     Private room             2        1.0       1.0   1.0  Real Bed
# 20029  Entire home/apt             4        1.0       2.0   2.0  Real Bed
#
#                                                amenities  security_deposit  \
# 0      {Internet,Wifi,"Paid parking off premises","Bu...             100.0
# 1      {Internet,Wifi,Kitchen,"Paid parking off premi...             300.0
# 2      {TV,Internet,Wifi,"Paid parking off premises",...               NaN
# 3      {TV,"Cable TV",Internet,Wifi,Kitchen,Elevator,...             300.0
# 4      {TV,Internet,Wifi,Breakfast,Heating,"Smoke det...               0.0
# 5      {TV,"Cable TV",Internet,Wifi,"Paid parking off...             150.0
# 6      {TV,"Cable TV",Internet,Wifi,"Pets live on thi...               NaN
# 7      {TV,"Cable TV",Internet,Wifi,"Smoking allowed"...               NaN
# 8      {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...               NaN
# 9      {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...             150.0
# 10     {TV,"Cable TV",Internet,Wifi,Heating,"Family/k...             300.0
# 11     {TV,Internet,Wifi,Kitchen,"Paid parking off pr...             300.0
# 12     {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...             100.0
# 13     {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...               0.0
# 14     {Wifi,Kitchen,"Paid parking off premises","Smo...               NaN
# 15     {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets all...             250.0
# 16     {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,"...             250.0
# 17     {TV,"Cable TV",Internet,Wifi,Kitchen,"Indoor f...               0.0
# 18     {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,"...             400.0
# 19     {TV,Wifi,Kitchen,"Paid parking off premises","...             100.0
# 20     {"Cable TV",Wifi,Kitchen,"Paid parking off pre...               0.0
# 21     {TV,"Cable TV",Internet,Wifi,Breakfast,Heating...               NaN
# 22     {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...               0.0
# 23     {TV,Internet,Wifi,"Paid parking off premises",...               0.0
# 24     {Internet,Wifi,"Smoking allowed",Heating,"Smok...               0.0
# 25     {Wifi,"Paid parking off premises","Buzzer/wire...             150.0
# 26     {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...               0.0
# 27     {Internet,Wifi,Kitchen,"Paid parking off premi...               0.0
# 28     {TV,"Cable TV",Internet,Wifi,"Wheelchair acces...             500.0
# 29     {TV,"Cable TV",Wifi,Kitchen,"Paid parking off ...               NaN
# ...                                                  ...               ...
# 20000  {TV,Wifi,Kitchen,Breakfast,Washer,"Fire exting...             500.0
# 20001  {TV,Wifi,Kitchen,Elevator,Heating,Washer,Essen...               NaN
# 20002  {TV,Wifi,Kitchen,Elevator,Heating,Washer,Essen...               NaN
# 20003  {Wifi,Kitchen,"Smoking allowed","Hot tub",Heat...               NaN
# 20004  {TV,Wifi,Kitchen,Heating,"Smoke detector","Fir...             100.0
# 20005  {Wifi,"Air conditioning",Heating,Essentials,Sh...               NaN
# 20006  {TV,"Cable TV",Wifi,Kitchen,"Smoking allowed",...             750.0
# 20007  {TV,Wifi,Kitchen,"Smoking allowed","Pets allow...               NaN
# 20008  {TV,Wifi,Kitchen,"Smoking allowed","Pets allow...               NaN
# 20009  {TV,Wifi,Kitchen,"Smoking allowed","Pets allow...               NaN
# 20010  {TV,Wifi,Kitchen,Heating,Washer,Dryer,Essentia...             250.0
# 20011  {TV,"Cable TV",Wifi,Kitchen,Heating,"Smoke det...               NaN
# 20012  {TV,Wifi,Kitchen,Heating,"Smoke detector",Esse...               NaN
# 20013  {TV,Wifi,Kitchen,Heating,"Smoke detector",Esse...               NaN
# 20014  {TV,Wifi,Kitchen,Heating,"Smoke detector",Esse...               NaN
# 20015  {TV,Wifi,Kitchen,Heating,"Smoke detector",Esse...               NaN
# 20016  {Wifi,"Air conditioning",Kitchen,"Smoking allo...             500.0
# 20017  {TV,Wifi,Kitchen,Heating,"Smoke detector","Car...               0.0
# 20018  {TV,Wifi,Kitchen,"Smoking allowed",Heating,Was...             250.0
# 20019  {TV,Wifi,Kitchen,"Smoking allowed",Breakfast,H...               0.0
# 20020  {TV,Wifi,Kitchen,"Free parking on premises","S...               NaN
# 20021  {TV,Wifi,Kitchen,Heating,Washer,Dryer,"Smoke d...             700.0
# 20022  {TV,Wifi,"Air conditioning",Kitchen,"Free park...               NaN
# 20023  {TV,Wifi,"Air conditioning",Pool,"Indoor firep...               NaN
# 20024  {Wifi,"Air conditioning",Kitchen,"Free parking...               NaN
# 20025  {TV,Wifi,Kitchen,"Free parking on premises",He...             500.0
# 20026     {TV,Wifi,Kitchen,Essentials,"Hair dryer",Iron}               0.0
# 20027  {TV,"Cable TV",Wifi,Kitchen,"Smoking allowed",...               NaN
# 20028     {TV,Wifi,Kitchen,Essentials,"Hair dryer",Iron}               NaN
# 20029  {TV,Wifi,Kitchen,"Pets allowed",Heating,Washer...               0.0
#
#        cleaning_fee  guests_included  extra_people  minimum_nights  \
# 0              50.0                1          20.0               3
# 1              40.0                2          15.0               4
# 2               NaN                2           0.0               1
# 3              40.0                2          10.0              14
# 4               0.0                1           0.0               2
# 5              15.0                2           0.0               3
# 6               NaN                1           0.0               2
# 7               NaN                1           0.0               2
# 8              60.0                4          30.0               3
# 9              40.0                2          75.0               3
# 10             35.0                1           0.0               3
# 11             50.0                4           0.0              28
# 12             60.0                2          30.0               2
# 13             50.0                2           0.0               3
# 14              NaN                2          20.0               3
# 15             50.0                2          50.0               3
# 16              NaN                2          25.0               2
# 17              0.0                4          50.0               5
# 18             50.0                2          50.0               3
# 19             75.0                4          45.0               3
# 20             30.0                2          50.0               1
# 21              NaN                1           0.0               2
# 22             60.0                3          25.0               4
# 23              0.0                1           0.0               3
# 24             25.0                2           0.0               1
# 25              NaN                1           0.0               3
# 26             25.0                3          25.0               3
# 27             15.0                1          20.0               1
# 28             50.0                1          50.0               3
# 29             35.0                2          35.0               5
# ...             ...              ...           ...             ...
# 20000          20.0                1           0.0               2
# 20001           NaN                1           0.0               3
# 20002           NaN                1           0.0               4
# 20003          50.0                1          10.0               4
# 20004          40.0                1           0.0               2
# 20005           NaN                1           0.0               1
# 20006          45.0                2          75.0               2
# 20007           5.0                1           0.0               1
# 20008           NaN                1           0.0               4
# 20009           NaN                1           0.0               1
# 20010          50.0                1           0.0               7
# 20011           NaN                1           0.0               1
# 20012           NaN                1           0.0               1
# 20013           NaN                1           0.0               1
# 20014           NaN                1           0.0               1
# 20015           NaN                1           0.0               1
# 20016          50.0                2          50.0               3
# 20017          50.0                1           0.0               2
# 20018           0.0                1           0.0              14
# 20019          30.0                3          30.0               3
# 20020           NaN                1           0.0               1
# 20021          40.0                1          20.0               2
# 20022           NaN                1           0.0               5
# 20023           NaN                1           0.0               7
# 20024           NaN                1           0.0               1
# 20025          60.0                1           0.0               7
# 20026          25.0                1           0.0               3
# 20027           NaN                1           0.0              10
# 20028           NaN                1           0.0               2
# 20029          30.0                1           0.0               5
#
#        maximum_nights calendar_updated  availability_30  availability_60  \
# 0                  15            today               17               44
# 1                  20      7 weeks ago                0                0
# 2                1000            today                0                7
# 3                  60       2 days ago                2               32
# 4                 730            today               16               37
# 5                  15     2 months ago               11               29
# 6                1825        yesterday                3               10
# 7                 730            today                1               10
# 8                 365    16 months ago                1               31
# 9                  21            today                8                8
# 10               1100            today               14               33
# 11                365       3 days ago                0                0
# 12               1125            today               16               16
# 13                730      2 weeks ago                0                0
# 14                365       4 days ago                7               34
# 15               1825    11 months ago                0                0
# 16                 60      5 weeks ago                0                0
# 17                 30       2 days ago               12               35
# 18                365      2 weeks ago               13               43
# 19                 15     2 months ago                3                3
# 20               1120       a week ago                0                0
# 21                365       3 days ago                8               25
# 22                 30            today               19               19
# 23                 80       1 week ago               11               11
# 24                150            today                1                2
# 25                 14      4 weeks ago               22               25
# 26                150            today                0               16
# 27                365            today                6               21
# 28                 31      6 weeks ago                0                0
# 29                 30       a week ago                0                2
# ...               ...              ...              ...              ...
# 20000            1125        yesterday               12               12
# 20001            1125        yesterday                2               28
# 20002            1125            today               12               13
# 20003            1125        yesterday                7                7
# 20004            1125            today               29               56
# 20005            1125        yesterday               10               31
# 20006            1125            today               14               15
# 20007            1125            today                3                3
# 20008              17        yesterday               19               22
# 20009            1125        yesterday                1                1
# 20010              14        yesterday               14               15
# 20011            1125            today                9               19
# 20012            1125            today               14               29
# 20013            1125            today                8               18
# 20014            1125            today               23               49
# 20015            1125            today                8               18
# 20016            1125            today                8                9
# 20017               6            today               23               23
# 20018              24            today                0               24
# 20019            1125        yesterday               23               53
# 20020            1125            today               22               33
# 20021              15        yesterday               10               18
# 20022              15            today               10               10
# 20023            1125            today               11               22
# 20024            1125            today                7               33
# 20025              12            today               11               11
# 20026              14            today               14               16
# 20027              22            today                0                3
# 20028              15            today                7               31
# 20029            1125            today               14               14
#
#        availability_90  availability_365  number_of_reviews first_review  \
# 0                   44                44                248   2009-03-30
# 1                    0                47                 42   2015-07-31
# 2                   24               198                233   2010-03-02
# 3                   44               141                  1   2018-01-21
# 4                   54               199                171   2012-01-09
# 5                   52               295                434   2010-05-16
# 6                   17               137                215   2010-08-22
# 7                   18               188                383   2011-03-16
# 8                   61               336                 32   2011-08-06
# 9                   11                11                 76   2010-11-25
# 10                  63                89                426   2010-09-06
# 11                   5                10                 61   2010-11-01
# 12                  16                16                176   2010-08-16
# 13                   0                 0                 31   2010-09-16
# 14                  34               253                 79   2010-09-02
# 15                   0                 0                  3   2010-09-16
# 16                   0                 0                167   2010-09-13
# 17                  61               276                159   2011-10-02
# 18                  73               296                 98   2011-05-14
# 19                   3                79                 12   2014-04-17
# 20                   0                 0                 91   2012-10-24
# 21                  37               206                213   2011-01-04
# 22                  19                19                152   2011-03-31
# 23                  11                11                 81   2010-11-03
# 24                   2                 2                333   2010-11-21
# 25                  43               289                261   2011-04-12
# 26                  35                47                219   2011-06-04
# 27                  47               129                120   2011-02-20
# 28                   0                 0                  3   2015-08-10
# 29                   2                32                 53   2010-12-06
# ...                ...               ...                ...          ...
# 20000               12                12                  0          NaT
# 20001               28                28                  0          NaT
# 20002               13                13                  0          NaT
# 20003                7                 7                  0          NaT
# 20004               56                56                  0          NaT
# 20005               46               167                  0          NaT
# 20006               15                15                  0          NaT
# 20007                3                 3                  1   2018-12-06
# 20008               22                22                  0          NaT
# 20009                1                 1                  0          NaT
# 20010               15                15                  0          NaT
# 20011               44               296                  0          NaT
# 20012               42               302                  0          NaT
# 20013               34               283                  0          NaT
# 20014               79               350                  0          NaT
# 20015               34               297                  0          NaT
# 20016                9                 9                  0          NaT
# 20017               23                23                  0          NaT
# 20018               39                42                  0          NaT
# 20019               83                83                  0          NaT
# 20020               34                34                  0          NaT
# 20021               18                23                  0          NaT
# 20022               15               234                  0          NaT
# 20023               30                30                  0          NaT
# 20024               56               133                  0          NaT
# 20025               11                11                  0          NaT
# 20026               16                16                  0          NaT
# 20027               22               210                  0          NaT
# 20028               31                31                  0          NaT
# 20029               14                14                  0          NaT
#
#       last_review  review_scores_rating  review_scores_accuracy  \
# 0      2018-11-28                  97.0                    10.0
# 1      2018-08-29                  96.0                    10.0
# 2      2018-11-30                  87.0                     9.0
# 3      2018-01-21                 100.0                    10.0
# 4      2018-11-25                  99.0                    10.0
# 5      2018-11-19                  93.0                     9.0
# 6      2018-12-03                  97.0                    10.0
# 7      2018-12-05                  95.0                    10.0
# 8      2017-10-16                  95.0                     9.0
# 9      2018-10-07                  95.0                    10.0
# ...
# 11                             9.0                     9.0
# 12                            10.0                    10.0
# 13                            10.0                     9.0
# 14                            10.0                    10.0
# 15                             9.0                     8.0
# 16                            10.0                    10.0
# 17                            10.0                    10.0
# 18                            10.0                    10.0
# 19                             9.0                     8.0
# 20                            10.0                    10.0
# 21                            10.0                    10.0
# 22                            10.0                     8.0
# 23                            10.0                     9.0
# 24                            10.0                    10.0
# 25                            10.0                     9.0
# 26                             9.0                     9.0
# 27                            10.0                    10.0
# 28                             9.0                    10.0
# 29                            10.0                    10.0
# ...                            ...                     ...
# 20000                          NaN                     NaN
# 20001                          NaN                     NaN
# 20002                          NaN                     NaN
# 20003                          NaN                     NaN
# 20004                          NaN                     NaN
# 20005                          NaN                     NaN
# 20006                          NaN                     NaN
# 20007                         10.0                    10.0
# 20008                          NaN                     NaN
# 20009                          NaN                     NaN
# 20010                          NaN                     NaN
# 20011                          NaN                     NaN
# 20012                          NaN                     NaN
# 20013                          NaN                     NaN
# 20014                          NaN                     NaN
# 20015                          NaN                     NaN
# 20016                          NaN                     NaN
# 20017                          NaN                     NaN
# 20018                          NaN                     NaN
# 20019                          NaN                     NaN
# 20020                          NaN                     NaN
# 20021                          NaN                     NaN
# 20022                          NaN                     NaN
# 20023                          NaN                     NaN
# 20024                          NaN                     NaN
# 20025                          NaN                     NaN
# 20026                          NaN                     NaN
# 20027                          NaN                     NaN
# 20028                          NaN                     NaN
# 20029                          NaN                     NaN
#
#        review_scores_value instant_bookable          cancellation_policy  \
# 0                     10.0                t  strict_14_with_grace_period
# 1                      9.0                f                     moderate
# 2                      9.0                f  strict_14_with_grace_period
# 3                     10.0                f  strict_14_with_grace_period
# 4                     10.0                t  strict_14_with_grace_period
# 5                      9.0                f                     moderate
# 6                     10.0                f                     moderate
# 7                     10.0                f                     moderate
# 8                      9.0                f                     moderate
# 9                      9.0                f                     moderate
# 10                     9.0                t  strict_14_with_grace_period
# 11                     8.0                f  strict_14_with_grace_period
# 12                     9.0                f  strict_14_with_grace_period
# 13                     9.0                f                     moderate
# 14                     9.0                t  strict_14_with_grace_period
# 15                     8.0                f                     flexible
# 16                     9.0                f                     flexible
# 17                     9.0                t  strict_14_with_grace_period
# 18                     9.0                f  strict_14_with_grace_period
# 19                     9.0                f                     moderate
# 20                     9.0                t  strict_14_with_grace_period
# 21                    10.0                f                     moderate
# 22                     9.0                f  strict_14_with_grace_period
# 23                     9.0                f  strict_14_with_grace_period
# 24                     9.0                t                     moderate
# 25                     9.0                t                     flexible
# 26                     9.0                t                     moderate
# 27                     9.0                f                     flexible
# 28                     9.0                t                     flexible
# 29                    10.0                f  strict_14_with_grace_period
# ...                    ...              ...                          ...
# 20000                  NaN                f  strict_14_with_grace_period
# 20001                  NaN                f                     flexible
# 20002                  NaN                f                     flexible
# 20003                  NaN                f                     moderate
# 20004                  NaN                f                     moderate
# 20005                  NaN                f                     flexible
# 20006                  NaN                t  strict_14_with_grace_period
# 20007                  8.0                t                     flexible
# 20008                  NaN                f  strict_14_with_grace_period
# 20009                  NaN                t                     flexible
# 20010                  NaN                f                     flexible
# 20011                  NaN                t                     moderate
# 20012                  NaN                t                     moderate
# 20013                  NaN                t                     moderate
# 20014                  NaN                t                     moderate
# 20015                  NaN                t                     moderate
# 20016                  NaN                f  strict_14_with_grace_period
# 20017                  NaN                f                     flexible
# 20018                  NaN                f  strict_14_with_grace_period
# 20019                  NaN                t  strict_14_with_grace_period
# 20020                  NaN                f                     flexible
# 20021                  NaN                f  strict_14_with_grace_period
# 20022                  NaN                t                     flexible
# 20023                  NaN                f                     flexible
# 20024                  NaN                f                     flexible
# 20025                  NaN                f  strict_14_with_grace_period
# 20026                  NaN                f                     flexible
# 20027                  NaN                f                     moderate
# 20028                  NaN                f                     flexible
# 20029                  NaN                t                     flexible
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 f                                f
# 2                                 f                                f
# 3                                 f                                f
# 4                                 f                                f
# 5                                 t                                t
# 6                                 f                                f
# 7                                 f                                f
# 8                                 f                                f
# 9                                 f                                f
# 10                                f                                t
# 11                                t                                t
# 12                                f                                f
# 13                                f                                f
# 14                                f                                f
# 15                                f                                f
# 16                                f                                f
# 17                                f                                t
# 18                                f                                f
# 19                                f                                f
# 20                                f                                f
# 21                                f                                f
# 22                                f                                f
# 23                                t                                f
# 24                                f                                f
# 25                                f                                f
# 26                                f                                f
# 27                                f                                f
# 28                                f                                f
# 29                                f                                f
# ...                             ...                              ...
# 20000                             f                                f
# 20001                             f                                f
# 20002                             f                                f
# 20003                             f                                f
# 20004                             f                                f
# 20005                             f                                f
# 20006                             f                                f
# 20007                             f                                f
# 20008                             f                                f
# 20009                             f                                f
# 20010                             f                                f
# 20011                             f                                f
# 20012                             f                                f
# 20013                             f                                f
# 20014                             f                                f
# 20015                             f                                f
# 20016                             f                                f
# 20017                             f                                f
# 20018                             f                                f
# 20019                             f                                f
# 20020                             f                                f
# 20021                             f                                f
# 20022                             f                                f
# 20023                             f                                f
# 20024                             f                                f
# 20025                             f                                f
# 20026                             f                                f
# 20027                             f                                f
# 20028                             f                                f
# 20029                             f                                f
#
#        calculated_host_listings_count  reviews_per_month
# 0                                   1               2.10
# 1                                   1               1.03
# 2                                   2               2.18
# 3                                   2               0.09
# 4                                   1               2.03
# 5                                   2               4.16
# 6                                   3               2.13
# 7                                   3               4.07
# 8                                   1               0.36
# 9                                   1               0.78
# 10                                  2               4.24
# 11                                  2               0.62
# 12                                  4               1.74
# 13                                  1               0.31
# 14                                  1               0.79
# 15                                  1               0.03
# 16                                  1               1.67
# 17                                  2               1.82
# 18                                  1               1.06
# 19                                  1               0.21
# 20                                  1               1.22
# 21                                  1               2.21
# 22                                  2               1.62
# 23                                  1               0.82
# 24                                  5               3.40
# 25                                  1               2.80
# 26                                  5               2.40
# 27                                  1               1.26
# 28                                  1               0.07
# 29                                  1               0.54
# ...                               ...                ...
# 20000                               1                NaN
# 20001                               2                NaN
# 20002                               2                NaN
# 20003                               2                NaN
# 20004                              38                NaN
# 20005                               1                NaN
# 20006                               1                NaN
# 20007                               1               1.00
# 20008                               3                NaN
# 20009                               1                NaN
# 20010                               1                NaN
# 20011                               5                NaN
# 20012                               5                NaN
# 20013                               5                NaN
# 20014                               5                NaN
# 20015                               5                NaN
# 20016                               1                NaN
# 20017                               1                NaN
# 20018                               1                NaN
# 20019                               1                NaN
# 20020                               1                NaN
# 20021                               1                NaN
# 20022                               1                NaN
# 20023                               1                NaN
# 20024                               1                NaN
# 20025                               1                NaN
# 20026                               2                NaN
# 20027                               2                NaN
# 20028                               2                NaN
# 20029                               1                NaN
#
# [20030 rows x 51 columns]

# %%
listings_new.host_response_time.unique()
# Out:
# array(['within an hour', 'within a few hours', 'a few days or more',
#        'within a day', nan], dtype=object)

# %%
#listings_new.to_csv('listings_new_2.csv')

# %%
listings_new.isnull().sum()
# Out:
# id                                     0
# name                                  38
# host_id                                0
# neighbourhood                          0
# latitude                               0
# longitude                              0
# price                                  0
# description                          124
# host_since                             4
# host_response_time                  9483
# host_response_rate                  9483
# host_is_superhost                      4
# host_listings_count                    4
# host_total_listings_count              4
# host_verifications                     0
# host_has_profile_pic                   4
# host_identity_verified                 4
# neighbourhood_cleansed                 0
# is_location_exact                      0
# property_type                          0
# room_type                              0
# accommodates                           0
# bathrooms                             10
# bedrooms                               8
# beds                                   7
# bed_type                               0
# amenities                              0
# security_deposit                    6166
# cleaning_fee                        3629
# guests_included                        0
# extra_people                           0
# minimum_nights                         0
# maximum_nights                         0
# calendar_updated                       0
# availability_30                        0
# availability_60                        0
# availability_90                        0
# availability_365                       0
# number_of_reviews                      0
# first_review                        2406
# last_review                         2406
# review_scores_rating                2639
# review_scores_accuracy              2649
# review_scores_cleanliness           2647
# review_scores_checkin               2661
# review_scores_communication         2652
# review_scores_location              2660
# review_scores_value                 2659
# instant_bookable                       0
# cancellation_policy                    0
# require_guest_profile_picture          0
# require_guest_phone_verification       0
# calculated_host_listings_count         0
# reviews_per_month                   2406
# dtype: int64

# %% [markdown]
# #### Reviews

# %%
reviews_details.head()
# Out:
#    listing_id    id        date  reviewer_id reviewer_name  \
# 0        2818  1191  2009-03-30        10952           Lam
# 1        2818  1771  2009-04-24        12798         Alice
# 2        2818  1989  2009-05-03        11869       Natalja
# 3        2818  2797  2009-05-18        14064       Enrique
# 4        2818  3151  2009-05-25        17977       Sherwin
#
#                                             comments
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...
# 2  We had such a great time in Amsterdam. Daniel ...
# 3  Very professional operation. Room is very clea...
# 4  Daniel is highly recommended.  He provided all...

# %%
reviews_details = reviews_details.drop(columns='reviewer_name')

# %%
reviews_details['date'] = pd.to_datetime(reviews_details['date'])

# %%
reviews_details.dtypes
# Out:
# listing_id              int64
# id                      int64
# date           datetime64[ns]
# reviewer_id             int64
# comments               object
# dtype: object

# %%
reviews_details.shape
# Out:
# (431830, 5)

# %%
test = reviews_details.iloc[:5,]
test
# Out:
#    listing_id    id       date  reviewer_id  \
# 0        2818  1191 2009-03-30        10952
# 1        2818  1771 2009-04-24        12798
# 2        2818  1989 2009-05-03        11869
# 3        2818  2797 2009-05-18        14064
# 4        2818  3151 2009-05-25        17977
#
#                                             comments
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...
# 2  We had such a great time in Amsterdam. Daniel ...
# 3  Very professional operation. Room is very clea...
# 4  Daniel is highly recommended.  He provided all...

# %%
analyzer = SentimentIntensityAnalyzer()

test['polarity_nltk'] = test['comments'].apply(lambda x: analyzer.polarity_scores(x))
test
# Out:
# C:\Users\anete\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    listing_id    id       date  reviewer_id  \
# 0        2818  1191 2009-03-30        10952
# 1        2818  1771 2009-04-24        12798
# 2        2818  1989 2009-05-03        11869
# 3        2818  2797 2009-05-18        14064
# 4        2818  3151 2009-05-25        17977
#
#                                             comments  \
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...
# 2  We had such a great time in Amsterdam. Daniel ...
# 3  Very professional operation. Room is very clea...
# 4  Daniel is highly recommended.  He provided all...
#
#                                        polarity_nltk
# 0  {'neg': 0.047, 'neu': 0.694, 'pos': 0.259, 'co...
# 1  {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'comp...
# 2  {'neg': 0.027, 'neu': 0.676, 'pos': 0.297, 'co...
# 3  {'neg': 0.0, 'neu': 0.53, 'pos': 0.47, 'compou...
# 4  {'neg': 0.0, 'neu': 0.742, 'pos': 0.258, 'comp...

# %%
test['polarity_tb'] = test['comments'].apply(lambda x: TextBlob(x).sentiment.polarity)
test
# Out:
# C:\Users\anete\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    listing_id    id       date  reviewer_id  \
# 0        2818  1191 2009-03-30        10952
# 1        2818  1771 2009-04-24        12798
# 2        2818  1989 2009-05-03        11869
# 3        2818  2797 2009-05-18        14064
# 4        2818  3151 2009-05-25        17977
#
#                                             comments  \
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...
# 2  We had such a great time in Amsterdam. Daniel ...
# 3  Very professional operation. Room is very clea...
# 4  Daniel is highly recommended.  He provided all...
#
#                                        polarity_nltk  polarity_tb
# 0  {'neg': 0.047, 'neu': 0.694, 'pos': 0.259, 'co...     0.140741
# 1  {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'comp...     0.365278
# 2  {'neg': 0.027, 'neu': 0.676, 'pos': 0.297, 'co...     0.313681
# 3  {'neg': 0.0, 'neu': 0.53, 'pos': 0.47, 'compou...     0.451111
# 4  {'neg': 0.0, 'neu': 0.742, 'pos': 0.258, 'comp...     0.222778

# %%
# boston housing prices dataset - how to predict price
# word cloud
